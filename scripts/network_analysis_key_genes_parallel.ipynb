# %% [markdown]
# # Network analysis
#
# This generates the three inputs for network analysis and calls the algorithm. This script only runs the analysis on the key genes rather than the whole differentially expressed gene list, in the interest of time.

# %%
import pandas as pd

# %% [markdown]
# Run this in the remote terminal:
# - screen
# - ipcluster start -n 3

# %%
import ipyparallel as ipp
client = ipp.Client()
view = client.load_balanced_view()
print("Connected engines:", len(client.ids))
# Out:
# Connected engines: 3

# %% [markdown]
# # Drug proximity analysis

# %% [markdown]
# ## Define functions
# The code from this chunk is taken from a paper by Han et al. (2021) titled "Identification of SARS-CoV-2–induced pathways reveals drug repurposing strategies".

# %%
# functions
def has_path(G,node_from,node_to): # returns true if the graph G has a path from source node(node_from) to target node (node_to)
    return(nx.has_path(G,node_from,node_to))


def get_shortest_path_length_between(G, source_id, target_id): #calculates shortest path length between source and target nodes in the graph G
    return nx.shortest_path_length(G, source_id, target_id) 

'''
The function below uses the previous two functions to calculate the path length 
between each source node (drug target) and its closest disease target.
See Guney 2015 for more details on the approach (Network-based in silico drug efficacy screening).
'''
def calculate_closest_distance(network, nodes_from, nodes_to):
    values_outer = []
    for node_from in nodes_from: #nodes_from is a list of drug targets (eg. from drugbank, chembl, etc.)
        values = [] # will store the shortest path length between a source node and all disease targets here
        for node_to in nodes_to: #nodes_to is a list of known disease targets
            # print("from - to", node_from, node_to)
            if not has_path(network,node_from,node_to): continue
            val = get_shortest_path_length_between(network, node_from, node_to)
            values.append(val)
        if len(values) == 0:    continue
        d = min(values) # the shortest path between a source node and its closest disease target
        # print (d)
        values_outer.append(d)
    closest_d = numpy.mean(values_outer) # the average shortest path length between any source node (drug target) and its closest disease target
    # print (d)
    return closest_d


def get_degree_binning(g, bin_size):
    '''
    This function creates the bins from a network g.
    Starting from a list of nodes with the lowest degree, it adds nodes with the same degree to the bin until it reaches the set bin size.
    If number of nodes with some degree is lower then bin size, it combines with other nodes with degree + 1 to meet bin size.
    '''
    degree_to_nodes = {}
    # the below two lines compute the degree of each node in the graph.
    # the setdefault method is used to add each node to a list of nodes with the same degree in the dictionary
    for node, degree in g.degree(): 
        degree_to_nodes.setdefault(degree, []).append(node)
    values = degree_to_nodes.keys()
    values = sorted(values) # values becomes a list, sorted from lowest to highest degree
    bins = []
    i = 0 # this is the iterator that iterates over each degree, starting from the first item in the list (lowest degree)
    while i < len(values):
        low = values[i] # this is the i-th degree in the values list
        val = degree_to_nodes[values[i]] # a list of the nodes with i-th degree (low)
        while len(val) < bin_size:
            # while the number of nodes in a bin is lower than the bin size, than nodes with degree i+1 will be added to the bin
            # bin size is chosen by the user - in the paper this is set to 100
            i += 1 # next iteration (move to the next degree in the list)
            if i == len(values): # breaks when the last item in the list is reached
                break
            # starting from a list of nodes with the lowest degree, it adds nodes with degree lowest + 1 to the val list until it reaches the set bin size
            val.extend(degree_to_nodes[values[i]]) # val will be extended with the next set of nodes with degree i+1 (low +1).
        if i == len(values):
            i -= 1
        high = values[i] # this is the highest degree
        i += 1
        # print i, low, high, len(val)
        if len(val) < bin_size:
            low_, high_, val_ = bins[-1]
            bins[-1] = (low_, high, val_ + val)
        else:
            bins.append((low, high, val))
    return bins

# this function lists all nodes in the same bin as each seed node
def get_degree_equivalents(seeds, bins, g): 
    seed_to_nodes = {}
    for seed in seeds:
        d = g.degree(seed) #extract degree of the seed node
        for l, h, nodes in bins: #it takes low, high degree and nodes for each bin
            if l <= d and h >= d:
                mod_nodes = list(nodes)
                mod_nodes.remove(seed)
                seed_to_nodes[seed] = mod_nodes
                break
    return seed_to_nodes

    
def pick_random_nodes_matching_selected(network, bins, nodes_selected, n_random, degree_aware=True, connected=False,
                                        seed=None):
    """
    Use get_degree_binning to get bins
    """
    if seed is not None:
        random.seed(seed)
    values = []
    nodes = network.nodes() # list of nodes in the network
    for i in range(n_random): # decided by the user (how many times will the random iterations be repeated?) usually this is = 1000
        if degree_aware:
            if connected:
                raise ValueError("Not implemented!")
            # the lines below pick random nodes matching the degree (same bin) of the real nodes
            nodes_random = set()
            node_to_equivalent_nodes = get_degree_equivalents(nodes_selected, bins, network) # lists nodes in the same bin as the node of interest
            # now choose a random node from the same bin as the real node
            for node, equivalent_nodes in node_to_equivalent_nodes.items():
                chosen = random.choice(equivalent_nodes)
                for k in range(20):  # Try to find a distinct node (at most 20 times) - to make sure it doesn't choose the same node
                    if chosen in nodes_random:
                        chosen = random.choice(equivalent_nodes)
                nodes_random.add(chosen)
            nodes_random = list(nodes_random)
        else:
            if connected:
                nodes_random = [random.choice(nodes)]
                k = 1
                while True:
                    if k == len(nodes_selected):
                        break
                    node_random = random.choice(nodes_random)
                    node_selected = random.choice(network.neighbors(node_random))
                    if node_selected in nodes_random:
                        continue
                    nodes_random.append(node_selected)
                    k += 1
            else:
                nodes_random = random.sample(nodes, len(nodes_selected))
        values.append(nodes_random)
    return values

def get_random_nodes(nodes, network, bins=None, n_random=1000, min_bin_size=100, degree_aware=True, seed=None):
    '''
    This function creates a n_random number of lists of random nodes with the same degree binning as the real nodes (when degree_aware=True).
    usually n_random = 1000 because we often do 1000 iterations.
    '''
    if bins is None:
        # Get degree bins of the network (if they aren't already supplied
        bins = get_degree_binning(network, min_bin_size)
    # pick the random nodes
    nodes_random = pick_random_nodes_matching_selected(network, bins, nodes, n_random, degree_aware,
                                                                         seed=seed)
    return nodes_random

def calculate_proximity(network, drug, nodes_from, nodes_to, nodes_from_random=None, nodes_to_random=None, bins=None,
                        n_random=1000, min_bin_size=100, seed=452456):
    """
    Calculate proximity from nodes_from to nodes_to
    If degree binning or random nodes are not given, they are generated
    """

    nodes_network = set(network.nodes())
    nodes_from = set(nodes_from) & nodes_network # select only nodes_from (drug targets) that are located in the network
    nodes_to = set(nodes_to) & nodes_network # select only nodes_to (disease targets) that are located in the network
    if len(nodes_from) == 0 or len(nodes_to) == 0:
        return None  # At least one of the node group not in network
    d = calculate_closest_distance(network, nodes_from, nodes_to) # this is the real distance
    
    # now do 1000 iterations using random nodes
    if bins is None and (nodes_from_random is None or nodes_to_random is None):
        bins = get_degree_binning(network, min_bin_size)
    if nodes_from_random is None:
        nodes_from_random = get_random_nodes(nodes_from, network, bins=bins, n_random=n_random,
                                             min_bin_size=min_bin_size, seed=seed)
    if nodes_to_random is None:
        nodes_to_random = get_random_nodes(nodes_to, network, bins=bins, n_random=n_random, min_bin_size=min_bin_size,
                                           seed=seed)
    random_values_list = zip(nodes_from_random, nodes_to_random)
    values = numpy.empty(len(nodes_from_random))  # n_random
    # now calculates the closest distance using random nodes. Repeat x1000
    for i, values_random in enumerate(random_values_list):
        #print('iteration ', i)
        nodes_from, nodes_to = values_random
        values[i] = calculate_closest_distance(network, nodes_from, nodes_to)
    m, s = numpy.mean(values), numpy.std(values) # do mean and stdev of random iterations
    if s == 0:
        z = 0.0
    else:
        z = (d - m) / s
    dict = {'drug': drug, 'distance': d, 'z_score': z}
    return dict

# %% [markdown]
# ## Call function

# %%
import networkx as nx
import pandas as pd
import sys, time
import numpy
import random

# %%
# Create PPI network
ppi_df = pd.read_csv("../data/networks/combined_PPI.csv", sep=",")
ppi_graph = nx.from_pandas_edgelist(ppi_df, "GeneA", "GeneB")

# Get degree bins
bins = get_degree_binning(ppi_graph, bin_size=100)

# Print basic information about the graph
print(f"Number of nodes in PPI graph: {ppi_graph.number_of_nodes()}")
print(f"Number of edges in PPI graph: {ppi_graph.number_of_edges()}")
# Out:
# Number of nodes in PPI graph: 18451
# Number of edges in PPI graph: 345547

# %%
# Prepare DPI data
dpi_df = pd.read_csv("../data/networks/combined_DPI.csv", sep=",")

# Drop NA
dpi_df.dropna(inplace=True)

# Filter DPI to keep only drug targets that are in the PPI graph
dpi_df = dpi_df[dpi_df["Drug_Target"].isin(ppi_graph.nodes)]
drug_list = dpi_df["Drug_Name"].unique()

# Print basic information about the DPI
print(f"Number of drug targets retained in DPI: {len(drug_list)}")

# Create a mapping of drug names to their targets
drug_to_targets = dpi_df.groupby("Drug_Name")["Drug_Target"].apply(set).to_dict()
# Out:
# Number of drug targets retained in DPI: 2244

# %% [markdown]
# ### Define function for proximity analysis

# %%
def run_proximity_analysis(step_name, deg_file_path, output_csv_path, ppi_graph, drug_to_targets,
                           bins, n_random=1000, min_bin_size=100, seed=452456):
    """
    Calculate proximity for step_name using drugs and targets in drug_to_targets and disease genes in deg_file_path
    Saves the result as a CSV file at output_csv_path
    """
    print(f"\n===== Processing {step_name} =====")
    
    # ========== LOAD DISEASE GENES ==========
    disease_genes = pd.read_csv(deg_file_path, header=None)
    print(len(disease_genes), f"disease genes in {step_name}")
    disease_genes = disease_genes.iloc[:,0].dropna().unique().tolist()
    # Keep only disease genes that are in the PPI graph
    disease_genes = [gene for gene in disease_genes if gene in ppi_graph.nodes]
    print(len(disease_genes), f"disease genes in {step_name} after filtering for PPI graph")
    
    # ========== GENERATE RANDOM SETS OF DISEASE GENES ==========
    # For each disease gene, pick a random node from the same degree bin, and repeat this 1000 times, generating 1000 sets of random disease genes
    random_disease_genes = get_random_nodes(
        disease_genes,
        ppi_graph,
        bins=bins,
        n_random=n_random,
        min_bin_size=min_bin_size,
        seed=seed,
        degree_aware=True)
    print("Generated", len(random_disease_genes), "sets of random disease genes")

    # ========== RUN PROXIMITY ANALYSIS ==========
    results = []
    # Iterate over each drug and calculate proximity to disease genes
    for i, (drug, targets) in enumerate(drug_to_targets.items()):
        start = time.time()
        print(f"Processing drug: {drug}")

        # Calculate proximity to disease genes
        result = calculate_proximity(
            ppi_graph,
            drug,
            targets,
            disease_genes,
            nodes_from_random=random_disease_genes,
            bins=bins,
            n_random=n_random,
            min_bin_size=min_bin_size,
            seed=seed
        )

        if result is not None:
            results.append(result)
        else:
            print(f"No proximity data for drug: {drug}")

        if i % 50 == 0:
            print(f"{i}/{len(drug_to_targets)} drugs processed")

        end = time.time()
        print(f"Runtime: {(end - start):.2f} sec.")

    # Save and display
    results_df = pd.DataFrame(results)
    results_df.to_csv(output_csv_path, index=False)
    print(f"Saved results to {output_csv_path}")
    print("Top 10 prioritised drugs for", step_name, results_df.sort_values("z_score").head(10))

# %% [markdown]
# ### Call function for each step

# %%
# Define DEG file paths and output paths
steps = {
    "step1": {
        "deg_file": "../results/humanPVATsn/network_analysis/step1_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_step1_key_only.csv"
    },
    "step2": {
        "deg_file": "../results/humanPVATsn/network_analysis/step2_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_step2_key_only.csv"
    },
    "step3": {
        "deg_file": "../results/humanPVATsn/network_analysis/step3_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_step3_key_only.csv"
    },
    "full": {
        "deg_file": "../results/humanPVATsn/network_analysis/full_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_full_key_only.csv"
    }
}

# Run proximity analysis for each step
# for step, path in steps.items(): CHANGE THIS BACK AFTERWARDS – I HAD A TYPO IN STEP 2 AND DID NOT WANT TO RERUN STEP 1
# for step in ["step2", "step3", "full"]: # DELETE THIS LINE AFTERWARDS
#    path = steps[step] # DELETE THIS LINE AFTERWARDS
 #   run_proximity_analysis(step_name=step,
 #                          deg_file_path=path["deg_file"],
  #                         output_csv_path=path["output_csv"],
   #                        ppi_graph=ppi_graph,
    #                       drug_to_targets=drug_to_targets,
     #                      bins=bins,
      #                     n_random=100,
       #                    min_bin_size=100,
        #                   seed=452456)
# Out:
# Runtime: 8.15 sec.
# Processing drug: hydroquinone
# Runtime: 9.16 sec.
# Processing drug: hydroxocobalamin
# Runtime: 6.84 sec.
# Processing drug: hydroxyamphetamine
# Runtime: 6.62 sec.
# Processing drug: hydroxyamphetamine hydrobromide
# Runtime: 7.45 sec.
# Processing drug: hydroxychloroquine
# Runtime: 8.84 sec.
# Processing drug: hydroxyurea
# Runtime: 7.28 sec.
# Processing drug: hydroxyzine
# Runtime: 7.98 sec.
# Processing drug: hyoscyamine
# Runtime: 7.36 sec.
# Processing drug: ibalizumab
# Runtime: 8.76 sec.
# Processing drug: ibandronate
# Runtime: 7.62 sec.
# Processing drug: ibandronic acid
# Runtime: 8.34 sec.
# Processing drug: ibritumomab tiuxetan
# Runtime: 9.40 sec.
# Processing drug: ibrutinib
# Runtime: 8.87 sec.
# Processing drug: ibuprofen
# Runtime: 7.43 sec.
# Processing drug: ibutilide
# Runtime: 7.41 sec.
# Processing drug: icatibant
# Runtime: 10.58 sec.
# Processing drug: idarubicin
# Runtime: 7.14 sec.
# Processing drug: idarubicin hydrochloride
# Runtime: 6.95 sec.
# Processing drug: idebenone
# Runtime: 7.02 sec.
# Processing drug: idecabtagene vicleucel
# Runtime: 8.10 sec.
# Processing drug: idelalisib
# Runtime: 9.40 sec.
# Processing drug: idoxuridine
# Runtime: 9.79 sec.
# Processing drug: ifenprodil
# Runtime: 10.45 sec.
# Processing drug: iloperidone
# Runtime: 8.39 sec.
# Processing drug: iloprost
# Runtime: 8.25 sec.
# Processing drug: imatinib
# Runtime: 7.67 sec.
# Processing drug: imatinib mesylate
# Runtime: 6.88 sec.
# Processing drug: imidapril
# Runtime: 6.74 sec.
# Processing drug: imipramine
# Runtime: 6.60 sec.
# Processing drug: imiquimod
# Runtime: 5.98 sec.
# Processing drug: inamrinone
# Runtime: 9.22 sec.
# Processing drug: inavolisib
# Runtime: 9.11 sec.
# Processing drug: inclisiran
# Runtime: 9.33 sec.
# Processing drug: indacaterol
# Runtime: 8.30 sec.
# Processing drug: indapamide
# Runtime: 7.20 sec.
# Processing drug: indecainide
# Runtime: 7.40 sec.
# Processing drug: indinavir sulfate
# Runtime: 6.56 sec.
# Processing drug: indomethacin
# Runtime: 9.74 sec.
# Processing drug: indoramin
# Runtime: 8.15 sec.
# Processing drug: inebilizumab
# Runtime: 8.09 sec.
# Processing drug: infigratinib
# Runtime: 8.01 sec.
# Processing drug: infigratinib phosphate
# Runtime: 8.15 sec.
# Processing drug: infliximab
# Runtime: 7.40 sec.
# Processing drug: ingenol mebutate
# Runtime: 6.40 sec.
# Processing drug: inotuzumab ozogamicin
# Runtime: 9.54 sec.
# Processing drug: insulin aspart
# Runtime: 12.29 sec.
# Processing drug: insulin beef
# Runtime: 9.10 sec.
# Processing drug: insulin degludec
# 1050/2244 drugs processed
# Runtime: 7.10 sec.
# Processing drug: insulin detemir
# Runtime: 8.28 sec.
# Processing drug: insulin glargine
# Runtime: 6.56 sec.
# Processing drug: insulin glulisine
# Runtime: 6.51 sec.
# Processing drug: insulin human
# Runtime: 6.26 sec.
# Processing drug: insulin icodec
# Runtime: 7.19 sec.
# Processing drug: insulin lispro
# Runtime: 7.50 sec.
# Processing drug: insulin pork
# Runtime: 8.58 sec.
# Processing drug: interferon alfa-2b
# Runtime: 9.91 sec.
# Processing drug: interferon alfa-n3
# Runtime: 9.00 sec.
# Processing drug: interferon beta-1a
# Runtime: 8.71 sec.
# Processing drug: interferon beta-1b
# Runtime: 7.31 sec.
# Processing drug: interferon gamma-1b
# Runtime: 10.04 sec.
# Processing drug: iodine
# Runtime: 7.95 sec.
# Processing drug: ioflupane
# Runtime: 8.64 sec.
# Processing drug: ipilimumab
# Runtime: 7.64 sec.
# Processing drug: ipratropium
# Runtime: 6.92 sec.
# Processing drug: iproniazid
# Runtime: 7.12 sec.
# Processing drug: irbesartan
# Runtime: 7.65 sec.
# Processing drug: irinotecan
# Runtime: 8.79 sec.
# Processing drug: iron
# Runtime: 6.82 sec.
# Processing drug: iron dextran
# Runtime: 6.71 sec.
# Processing drug: isatuximab
# Runtime: 7.19 sec.
# Processing drug: isavuconazole
# Runtime: 7.35 sec.
# Processing drug: isocarboxazid
# Runtime: 8.42 sec.
# Processing drug: isoconazole
# Runtime: 7.53 sec.
# Processing drug: isoetharine
# Runtime: 5.66 sec.
# Processing drug: isoetharine mesylate
# Runtime: 6.63 sec.
# Processing drug: isoflurane
# Runtime: 7.36 sec.
# Processing drug: isoflurophate
# Runtime: 6.57 sec.
# Processing drug: isometheptene
# Runtime: 6.03 sec.
# Processing drug: isoniazid
# Runtime: 5.32 sec.
# Processing drug: isoprenaline
# Runtime: 4.97 sec.
# Processing drug: isopropamide iodide
# Runtime: 5.81 sec.
# Processing drug: isoproterenol
# Runtime: 5.13 sec.
# Processing drug: isoproterenol hydrochloride
# Runtime: 4.86 sec.
# Processing drug: isosorbide dinitrate
# Runtime: 4.96 sec.
# Processing drug: isosorbide mononitrate
# Runtime: 4.93 sec.
# Processing drug: isotretinoin
# Runtime: 6.13 sec.
# Processing drug: isoxsuprine
# Runtime: 6.03 sec.
# Processing drug: isradipine
# Runtime: 5.68 sec.
# Processing drug: istradefylline
# Runtime: 5.94 sec.
# Processing drug: itacitinib
# Runtime: 4.88 sec.
# Processing drug: itraconazole
# Runtime: 5.60 sec.
# Processing drug: ivabradine
# Runtime: 5.55 sec.
# Processing drug: ivacaftor
# Runtime: 4.95 sec.
# Processing drug: ivermectin
# Runtime: 4.76 sec.
# Processing drug: ivosidenib
# Runtime: 4.76 sec.
# Processing drug: ixabepilone
# Runtime: 5.20 sec.
# Processing drug: ixazomib
# Runtime: 5.59 sec.
# Processing drug: ixekizumab
# 1100/2244 drugs processed
# Runtime: 5.95 sec.
# Processing drug: kanamycin
# Runtime: 5.55 sec.
# Processing drug: ketamine
# Runtime: 5.47 sec.
# Processing drug: ketanserin
# Runtime: 5.73 sec.
# Processing drug: ketoconazole
# Runtime: 7.74 sec.
# Processing drug: ketoprofen
# Runtime: 5.20 sec.
# Processing drug: ketorolac
# Runtime: 6.36 sec.
# Processing drug: ketorolac tromethamine
# Runtime: 5.55 sec.
# Processing drug: ketotifen
# Runtime: 5.19 sec.
# Processing drug: ketotifen fumarate
# Runtime: 6.45 sec.
# Processing drug: labetalol
# Runtime: 5.86 sec.
# Processing drug: labetalol hydrochloride
# Runtime: 4.89 sec.
# Processing drug: lacidipine
# Runtime: 4.90 sec.
# Processing drug: lacosamide
# Runtime: 4.85 sec.
# Processing drug: lamivudine
# Runtime: 4.88 sec.
# Processing drug: lamotrigine
# Runtime: 4.83 sec.
# Processing drug: lanadelumab
# Runtime: 5.24 sec.
# Processing drug: landiolol
# Runtime: 5.42 sec.
# Processing drug: lanreotide
# Runtime: 4.93 sec.
# Processing drug: lansoprazole
# Runtime: 4.89 sec.
# Processing drug: lapatinib
# Runtime: 5.29 sec.
# Processing drug: lapatinib ditosylate
# Runtime: 6.58 sec.
# Processing drug: laropiprant
# Runtime: 5.84 sec.
# Processing drug: larotrectinib
# Runtime: 6.02 sec.
# Processing drug: larotrectinib sulfate
# Runtime: 4.96 sec.
# Processing drug: lasmiditan
# Runtime: 4.93 sec.
# Processing drug: lasofoxifene
# Runtime: 5.03 sec.
# Processing drug: latanoprost
# Runtime: 5.02 sec.
# Processing drug: lauric acid
# Runtime: 5.06 sec.
# Processing drug: lazertinib
# Runtime: 5.05 sec.
# Processing drug: lebrikizumab
# Runtime: 4.89 sec.
# Processing drug: lecanemab
# Runtime: 5.01 sec.
# Processing drug: lefamulin
# Runtime: 4.99 sec.
# Processing drug: leflunomide
# Runtime: 5.13 sec.
# Processing drug: lemborexant
# Runtime: 5.09 sec.
# Processing drug: lenalidomide
# Runtime: 4.88 sec.
# Processing drug: leniolisib
# Runtime: 5.00 sec.
# Processing drug: lenvatinib
# Runtime: 4.93 sec.
# Processing drug: lesinurad
# Runtime: 4.98 sec.
# Processing drug: letibotulinumtoxina
# Runtime: 4.77 sec.
# Processing drug: letrozole
# Runtime: 4.99 sec.
# Processing drug: leucovorin
# Runtime: 4.84 sec.
# Processing drug: leuprolide
# Runtime: 4.90 sec.
# Processing drug: leuprolide acetate
# Runtime: 4.91 sec.
# Processing drug: levallorphan
# Runtime: 4.91 sec.
# Processing drug: levamisole
# Runtime: 5.22 sec.
# Processing drug: levamisole hydrochloride
# Runtime: 5.57 sec.
# Processing drug: levamlodipine
# Runtime: 4.93 sec.
# Processing drug: levetiracetam
# Runtime: 5.05 sec.
# Processing drug: levobunolol
# Runtime: 6.39 sec.
# Processing drug: levobupivacaine
# 1150/2244 drugs processed
# Runtime: 5.59 sec.
# Processing drug: levobupivacaine hydrochloride
# Runtime: 5.34 sec.
# Processing drug: levocabastine
# Runtime: 4.99 sec.
# Processing drug: levocetirizine
# Runtime: 4.98 sec.
# Processing drug: levocetirizine dihydrochloride
# Runtime: 5.02 sec.
# Processing drug: levodopa
# Runtime: 4.95 sec.
# Processing drug: levofloxacin
# Runtime: 4.94 sec.
# Processing drug: levoketoconazole
# Runtime: 5.93 sec.
# Processing drug: levomenthol
# Runtime: 5.69 sec.
# Processing drug: levomepromazine
# Runtime: 5.79 sec.
# Processing drug: levomethadyl acetate
# Runtime: 6.12 sec.
# Processing drug: levomilnacipran
# Runtime: 5.23 sec.
# Processing drug: levonorgestrel
# Runtime: 5.22 sec.
# Processing drug: levopropoxyphene
# Runtime: 5.48 sec.
# Processing drug: levorphanol
# Runtime: 6.99 sec.
# Processing drug: levosalbutamol
# Runtime: 8.59 sec.
# Processing drug: levothyroxine
# Runtime: 8.57 sec.
# Processing drug: lidocaine
# Runtime: 11.23 sec.
# Processing drug: lidoflazine
# Runtime: 8.13 sec.
# Processing drug: lifitegrast
# Runtime: 7.15 sec.
# Processing drug: linaclotide
# Runtime: 5.99 sec.
# Processing drug: linagliptin
# Runtime: 8.88 sec.
# Processing drug: lincomycin
# Runtime: 8.85 sec.
# Processing drug: lindane
# Runtime: 8.38 sec.
# Processing drug: linezolid
# Runtime: 7.42 sec.
# Processing drug: linzagolix
# Runtime: 7.10 sec.
# Processing drug: liothyronine
# Runtime: 7.85 sec.
# Processing drug: liothyronine sodium
# Runtime: 6.87 sec.
# Processing drug: liotrix
# Runtime: 7.02 sec.
# Processing drug: lipegfilgrastim
# Runtime: 7.52 sec.
# Processing drug: lipoic acid, alpha
# Runtime: 8.23 sec.
# Processing drug: liraglutide
# Runtime: 9.10 sec.
# Processing drug: lisdexamfetamine
# Runtime: 9.12 sec.
# Processing drug: lisinopril
# Runtime: 7.12 sec.
# Processing drug: lisinopril anhydrous
# Runtime: 6.62 sec.
# Processing drug: lisocabtagene maraleucel
# Runtime: 6.23 sec.
# Processing drug: lisuride
# Runtime: 5.92 sec.
# Processing drug: lixisenatide
# Runtime: 9.85 sec.
# Processing drug: lodoxamide
# Runtime: 7.34 sec.
# Processing drug: lofexidine
# Runtime: 7.70 sec.
# Processing drug: lomefloxacin
# Runtime: 7.77 sec.
# Processing drug: lomitapide
# Runtime: 8.06 sec.
# Processing drug: lonafarnib
# Runtime: 7.17 sec.
# Processing drug: lonapegsomatropin
# Runtime: 7.06 sec.
# Processing drug: loncastuximab tesirine
# Runtime: 6.41 sec.
# Processing drug: lonoctocog alfa
# Runtime: 6.36 sec.
# Processing drug: loperamide
# Runtime: 6.48 sec.
# Processing drug: loperamide hydrochloride
# Runtime: 7.11 sec.
# Processing drug: lopinavir
# Runtime: 6.71 sec.
# Processing drug: loratadine
# Runtime: 7.47 sec.
# Processing drug: lorazepam
# 1200/2244 drugs processed
# Runtime: 6.63 sec.
# Processing drug: lorcaserin
# Runtime: 8.36 sec.
# Processing drug: lorlatinib
# Runtime: 7.38 sec.
# Processing drug: lornoxicam
# Runtime: 6.72 sec.
# Processing drug: lorpiprazole
# Runtime: 7.02 sec.
# Processing drug: losartan
# Runtime: 6.47 sec.
# Processing drug: losartan potassium
# Runtime: 6.50 sec.
# Processing drug: loteprednol etabonate
# Runtime: 6.13 sec.
# Processing drug: lovastatin
# Runtime: 7.74 sec.
# Processing drug: loxapine
# Runtime: 7.84 sec.
# Processing drug: loxapine succinate
# Runtime: 6.31 sec.
# Processing drug: loxoprofen
# Runtime: 6.20 sec.
# Processing drug: lubiprostone
# Runtime: 6.54 sec.
# Processing drug: lumacaftor
# Runtime: 5.67 sec.
# Processing drug: lumateperone
# Runtime: 5.79 sec.
# Processing drug: lumefantrine
# Runtime: 6.48 sec.
# Processing drug: lumiracoxib
# Runtime: 7.42 sec.
# Processing drug: lurasidone
# Runtime: 8.49 sec.
# Processing drug: lusutrombopag
# Runtime: 6.17 sec.
# Processing drug: lutetium lu 177 dotatate
# Runtime: 8.60 sec.
# Processing drug: lutetium lu-177 vipivotide tetraxetan
# Runtime: 7.26 sec.
# Processing drug: lutropin alfa
# Runtime: 7.19 sec.
# Processing drug: lypressin
# Runtime: 7.32 sec.
# Processing drug: lysine
# Runtime: 7.43 sec.
# Processing drug: macimorelin
# Runtime: 7.25 sec.
# Processing drug: macitentan
# Runtime: 6.65 sec.
# Processing drug: mafenide
# Runtime: 8.38 sec.
# Processing drug: magnesium salicylate
# Runtime: 7.16 sec.
# Processing drug: malathion
# Runtime: 7.82 sec.
# Processing drug: maprotiline
# Runtime: 6.85 sec.
# Processing drug: maprotiline hydrochloride
# Runtime: 6.57 sec.
# Processing drug: maralixibat
# Runtime: 5.94 sec.
# Processing drug: maralixibat chloride
# Runtime: 6.99 sec.
# Processing drug: maraviroc
# Runtime: 7.98 sec.
# Processing drug: margetuximab
# Runtime: 5.61 sec.
# Processing drug: maribavir
# Runtime: 6.00 sec.
# Processing drug: marstacimab
# Runtime: 6.36 sec.
# Processing drug: masitinib
# Runtime: 5.68 sec.
# Processing drug: mavacamten
# Runtime: 5.74 sec.
# Processing drug: mavorixafor
# Runtime: 7.22 sec.
# Processing drug: mazindol
# Runtime: 6.04 sec.
# Processing drug: mebendazole
# Runtime: 5.80 sec.
# Processing drug: mecamylamine
# Runtime: 5.64 sec.
# Processing drug: mecasermin
# Runtime: 5.82 sec.
# Processing drug: mecasermin rinfabate
# Runtime: 5.43 sec.
# Processing drug: meclizine
# Runtime: 5.62 sec.
# Processing drug: meclofenamic acid
# Runtime: 7.09 sec.
# Processing drug: mecobalamin
# Runtime: 6.88 sec.
# Processing drug: medroxyprogesterone acetate
# Runtime: 6.67 sec.
# Processing drug: medrysone
# Runtime: 6.25 sec.
# Processing drug: mefenamic acid
# 1250/2244 drugs processed
# Runtime: 7.10 sec.
# Processing drug: mefloquine
# Runtime: 8.66 sec.
# Processing drug: mefloquine hydrochloride
# Runtime: 9.02 sec.
# Processing drug: megestrol
# Runtime: 6.81 sec.
# Processing drug: megestrol acetate
# Runtime: 6.67 sec.
# Processing drug: melatonin
# Runtime: 7.19 sec.
# Processing drug: meloxicam
# Runtime: 5.69 sec.
# Processing drug: melphalan
# Runtime: 5.25 sec.
# Processing drug: memantine
# Runtime: 5.79 sec.
# Processing drug: memantine hydrochloride
# Runtime: 5.64 sec.
# Processing drug: menotropins
# Runtime: 5.82 sec.
# Processing drug: menthol
# Runtime: 5.80 sec.
# Processing drug: menthyl salicylate
# Runtime: 7.29 sec.
# Processing drug: mepenzolate bromide
# Runtime: 6.03 sec.
# Processing drug: meperidine
# Runtime: 5.31 sec.
# Processing drug: meperidine hydrochloride
# Runtime: 5.09 sec.
# Processing drug: mephenytoin
# Runtime: 4.97 sec.
# Processing drug: mepivacaine
# Runtime: 5.23 sec.
# Processing drug: mepolizumab
# Runtime: 4.91 sec.
# Processing drug: meptazinol
# Runtime: 4.80 sec.
# Processing drug: mepyramine
# Runtime: 5.19 sec.
# Processing drug: mercaptopurine
# Runtime: 5.44 sec.
# Processing drug: mercaptopurine anhydrous
# Runtime: 6.12 sec.
# Processing drug: mesalamine
# Runtime: 4.86 sec.
# Processing drug: mesalazine
# Runtime: 4.74 sec.
# Processing drug: mesoridazine
# Runtime: 4.92 sec.
# Processing drug: mesterolone
# Runtime: 4.78 sec.
# Processing drug: mestranol
# Runtime: 4.74 sec.
# Processing drug: metaproterenol
# Runtime: 4.65 sec.
# Processing drug: metaraminol
# Runtime: 4.93 sec.
# Processing drug: metergoline
# Runtime: 5.00 sec.
# Processing drug: metformin
# Runtime: 5.04 sec.
# Processing drug: methacholine
# Runtime: 5.18 sec.
# Processing drug: methacholine chloride
# Runtime: 5.27 sec.
# Processing drug: methacycline
# Runtime: 4.86 sec.
# Processing drug: methacycline hydrochloride
# Runtime: 4.86 sec.
# Processing drug: methadone
# Runtime: 4.92 sec.
# Processing drug: methamphetamine
# Runtime: 4.82 sec.
# Processing drug: methantheline
# Runtime: 4.92 sec.
# Processing drug: methazolamide
# Runtime: 4.86 sec.
# Processing drug: methdilazine
# Runtime: 4.86 sec.
# Processing drug: methimazole
# Runtime: 5.07 sec.
# Processing drug: methionine
# Runtime: 5.07 sec.
# Processing drug: methohexital
# Runtime: 5.13 sec.
# Processing drug: methotrexate
# Runtime: 6.03 sec.
# Processing drug: methotrimeprazine
# Runtime: 5.67 sec.
# Processing drug: methoxamine
# Runtime: 7.12 sec.
# Processing drug: methoxsalen
# Runtime: 5.21 sec.
# Processing drug: methoxy polyethylene glycol-epoetin beta
# Runtime: 5.27 sec.
# Processing drug: methoxyphenamine
# Runtime: 5.56 sec.
# Processing drug: methscopolamine
# 1300/2244 drugs processed
# Runtime: 6.55 sec.
# Processing drug: methscopolamine bromide
# Runtime: 5.46 sec.
# Processing drug: methsuximide
# Runtime: 5.29 sec.
# Processing drug: methyldopa
# Runtime: 5.34 sec.
# Processing drug: methylene blue
# Runtime: 5.48 sec.
# Processing drug: methylene blue anhydrous
# Runtime: 6.54 sec.
# Processing drug: methylene blue cation
# Runtime: 5.57 sec.
# Processing drug: methylergometrine
# Runtime: 5.59 sec.
# Processing drug: methylergonovine
# Runtime: 5.85 sec.
# Processing drug: methylnaltrexone
# Runtime: 5.56 sec.
# Processing drug: methylnaltrexone bromide
# Runtime: 6.85 sec.
# Processing drug: methylphenidate
# Runtime: 5.82 sec.
# Processing drug: methylphenidate hydrochloride
# Runtime: 7.49 sec.
# Processing drug: methylphenobarbital
# Runtime: 9.21 sec.
# Processing drug: methylprednisolone
# Runtime: 7.52 sec.
# Processing drug: methylpromazine
# Runtime: 6.83 sec.
# Processing drug: methyltestosterone
# Runtime: 6.05 sec.
# Processing drug: methysergide
# Runtime: 5.25 sec.
# Processing drug: methysergide maleate
# Runtime: 5.05 sec.
# Processing drug: metoclopramide
# Runtime: 5.18 sec.
# Processing drug: metocurine
# Runtime: 5.06 sec.
# Processing drug: metolazone
# Runtime: 4.99 sec.
# Processing drug: metoprolol
# Runtime: 4.97 sec.
# Processing drug: metoprolol tartrate
# Runtime: 5.01 sec.
# Processing drug: metreleptin
# Runtime: 5.00 sec.
# Processing drug: metronidazole
# Runtime: 5.16 sec.
# Processing drug: metyrapone
# Runtime: 5.02 sec.
# Processing drug: metyrosine
# Runtime: 4.96 sec.
# Processing drug: mexiletine
# Runtime: 4.96 sec.
# Processing drug: mexiletine hydrochloride
# Runtime: 4.90 sec.
# Processing drug: mianserin
# Runtime: 5.02 sec.
# Processing drug: mibefradil
# Runtime: 5.04 sec.
# Processing drug: mibefradil dihydrochloride
# Runtime: 5.01 sec.
# Processing drug: micafungin
# Runtime: 6.52 sec.
# Processing drug: miconazole
# Runtime: 7.92 sec.
# Processing drug: miconazole nitrate
# Runtime: 6.76 sec.
# Processing drug: midazolam
# Runtime: 6.70 sec.
# Processing drug: midodrine
# Runtime: 7.04 sec.
# Processing drug: midostaurin
# Runtime: 5.89 sec.
# Processing drug: mifamurtide
# Runtime: 5.19 sec.
# Processing drug: mifepristone
# Runtime: 5.33 sec.
# Processing drug: migalastat
# Runtime: 5.27 sec.
# Processing drug: miglitol
# Runtime: 5.13 sec.
# Processing drug: miglustat
# Runtime: 5.24 sec.
# Processing drug: milnacipran
# Runtime: 5.24 sec.
# Processing drug: milrinone
# Runtime: 5.34 sec.
# Processing drug: miltefosine
# Runtime: 5.32 sec.
# Processing drug: minaprine
# Runtime: 6.00 sec.
# Processing drug: minocycline
# Runtime: 5.77 sec.
# Processing drug: minoxidil
# Runtime: 5.28 sec.
# Processing drug: mirabegron
# 1350/2244 drugs processed
# Runtime: 6.59 sec.
# Processing drug: mirdametinib
# Runtime: 6.35 sec.
# Processing drug: mirikizumab
# Runtime: 5.43 sec.
# Processing drug: mirtazapine
# Runtime: 5.13 sec.
# Processing drug: mirvetuximab soravtansine
# Runtime: 5.38 sec.
# Processing drug: misoprostol
# Runtime: 5.27 sec.
# Processing drug: mitapivat
# Runtime: 5.15 sec.
# Processing drug: mitomycin
# Runtime: 5.54 sec.
# Processing drug: mitotane
# Runtime: 5.69 sec.
# Processing drug: mitoxantrone
# Runtime: 6.76 sec.
# Processing drug: mitoxantrone hydrochloride
# Runtime: 5.31 sec.
# Processing drug: mizolastine
# Runtime: 5.16 sec.
# Processing drug: mobocertinib
# Runtime: 5.23 sec.
# Processing drug: moclobemide
# Runtime: 5.42 sec.
# Processing drug: modafinil
# Runtime: 5.54 sec.
# Processing drug: moexipril
# Runtime: 5.77 sec.
# Processing drug: mogamulizumab
# Runtime: 6.39 sec.
# Processing drug: molindone
# Runtime: 5.82 sec.
# Processing drug: molsidomine
# Runtime: 5.79 sec.
# Processing drug: momelotinib
# Runtime: 5.32 sec.
# Processing drug: mometasone
# Runtime: 5.47 sec.
# Processing drug: mometasone furoate
# Runtime: 5.35 sec.
# Processing drug: monobenzone
# Runtime: 5.42 sec.
# Processing drug: monomethyl fumarate
# Runtime: 5.65 sec.
# Processing drug: montelukast
# Runtime: 5.51 sec.
# Processing drug: montelukast sodium
# Runtime: 5.84 sec.
# Processing drug: moroctocog alfa
# Runtime: 8.09 sec.
# Processing drug: morphine
# Runtime: 9.08 sec.
# Processing drug: mosunetuzumab
# Runtime: 9.70 sec.
# Processing drug: moxalactam
# Runtime: 8.51 sec.
# Processing drug: moxetumomab pasudotox
# Runtime: 8.56 sec.
# Processing drug: moxifloxacin
# Runtime: 6.61 sec.
# Processing drug: moxisylyte
# Runtime: 6.62 sec.
# Processing drug: moxonidine
# Runtime: 8.03 sec.
# Processing drug: mupirocin
# Runtime: 7.37 sec.
# Processing drug: mycophenolate mofetil
# Runtime: 9.13 sec.
# Processing drug: mycophenolic acid
# Runtime: 8.77 sec.
# Processing drug: nabilone
# Runtime: 7.92 sec.
# Processing drug: nabumetone
# Runtime: 6.42 sec.
# Processing drug: nadolol
# Runtime: 6.40 sec.
# Processing drug: nadroparin
# Runtime: 6.21 sec.
# Processing drug: nafarelin
# Runtime: 6.34 sec.
# Processing drug: naftifine
# Runtime: 6.16 sec.
# Processing drug: nalbuphine
# Runtime: 5.56 sec.
# Processing drug: naldemedine
# Runtime: 6.19 sec.
# Processing drug: nalidixic acid
# Runtime: 6.38 sec.
# Processing drug: nalmefene
# Runtime: 5.53 sec.
# Processing drug: naloxegol
# Runtime: 6.53 sec.
# Processing drug: naloxone
# Runtime: 7.69 sec.
# Processing drug: naloxone hydrochloride
# Runtime: 6.89 sec.
# Processing drug: naltrexone
# 1400/2244 drugs processed
# Runtime: 5.96 sec.
# Processing drug: naltrexone hydrochloride
# Runtime: 5.79 sec.
# Processing drug: naphazoline
# Runtime: 5.72 sec.
# Processing drug: naphazoline hydrochloride
# Runtime: 5.72 sec.
# Processing drug: naproxen
# Runtime: 5.71 sec.
# Processing drug: naratriptan
# Runtime: 5.69 sec.
# Processing drug: natalizumab
# Runtime: 5.45 sec.
# Processing drug: nateglinide
# Runtime: 6.00 sec.
# Processing drug: nebivolol
# Runtime: 5.76 sec.
# Processing drug: necitumumab
# Runtime: 5.70 sec.
# Processing drug: nedocromil
# Runtime: 5.74 sec.
# Processing drug: nedosiran
# Runtime: 6.55 sec.
# Processing drug: nefazodone
# Runtime: 6.15 sec.
# Processing drug: nefazodone hydrochloride
# Runtime: 6.41 sec.
# Processing drug: nelarabine
# Runtime: 6.90 sec.
# Processing drug: nelfinavir
# Runtime: 6.88 sec.
# Processing drug: nemolizumab
# Runtime: 6.02 sec.
# Processing drug: neostigmine
# Runtime: 6.10 sec.
# Processing drug: neostigmine bromide
# Runtime: 5.70 sec.
# Processing drug: neostigmine methylsulfate
# Runtime: 6.11 sec.
# Processing drug: nepafenac
# Runtime: 7.92 sec.
# Processing drug: neratinib
# Runtime: 8.21 sec.
# Processing drug: netarsudil
# Runtime: 7.36 sec.
# Processing drug: netilmicin
# Runtime: 6.60 sec.
# Processing drug: netupitant
# Runtime: 6.08 sec.
# Processing drug: nevirapine
# Runtime: 6.15 sec.
# Processing drug: nicardipine
# Runtime: 7.31 sec.
# Processing drug: nicergoline
# Runtime: 5.81 sec.
# Processing drug: niclosamide
# Runtime: 8.80 sec.
# Processing drug: nicotinamide
# Runtime: 6.64 sec.
# Processing drug: nicotine
# Runtime: 6.72 sec.
# Processing drug: nifedipine
# Runtime: 6.48 sec.
# Processing drug: nifuroxazide
# Runtime: 7.85 sec.
# Processing drug: nilotinib
# Runtime: 7.26 sec.
# Processing drug: nilutamide
# Runtime: 6.21 sec.
# Processing drug: nilvadipine
# Runtime: 6.11 sec.
# Processing drug: nimesulide
# Runtime: 5.92 sec.
# Processing drug: nimodipine
# Runtime: 5.79 sec.
# Processing drug: nintedanib
# Runtime: 7.88 sec.
# Processing drug: nintedanib esylate
# Runtime: 6.80 sec.
# Processing drug: niraparib
# Runtime: 7.03 sec.
# Processing drug: nirogacestat
# Runtime: 6.36 sec.
# Processing drug: nisoldipine
# Runtime: 6.33 sec.
# Processing drug: nitazoxanide
# Runtime: 6.21 sec.
# Processing drug: nitisinone
# Runtime: 6.98 sec.
# Processing drug: nitrazepam
# Runtime: 5.41 sec.
# Processing drug: nitrendipine
# Runtime: 6.31 sec.
# Processing drug: nitric oxide
# Runtime: 6.29 sec.
# Processing drug: nitrofurantoin
# Runtime: 7.87 sec.
# Processing drug: nitrofurazone
# Runtime: 6.77 sec.
# Processing drug: nitroprusside
# 1450/2244 drugs processed
# Runtime: 10.04 sec.
# Processing drug: nitrous acid
# Runtime: 9.36 sec.
# Processing drug: nivolumab
# Runtime: 8.58 sec.
# Processing drug: nizatidine
# Runtime: 5.52 sec.
# Processing drug: nogapendekin alfa
# Runtime: 5.43 sec.
# Processing drug: nonacog beta pegol
# Runtime: 5.36 sec.
# Processing drug: nonivamide
# Runtime: 5.57 sec.
# Processing drug: norelgestromin
# Runtime: 5.47 sec.
# Processing drug: norepinephrine
# Runtime: 5.69 sec.
# Processing drug: norethindrone
# Runtime: 6.52 sec.
# Processing drug: norethindrone acetate
# Runtime: 6.09 sec.
# Processing drug: norethisterone
# Runtime: 5.75 sec.
# Processing drug: norfloxacin
# Runtime: 5.94 sec.
# Processing drug: norgestimate
# Runtime: 5.73 sec.
# Processing drug: norgestrel
# Runtime: 5.75 sec.
# Processing drug: nortriptyline
# Runtime: 5.97 sec.
# Processing drug: nortriptyline hydrochloride
# Runtime: 6.26 sec.
# Processing drug: noscapine
# Runtime: 5.57 sec.
# Processing drug: novobiocin
# Runtime: 7.40 sec.
# Processing drug: nusinersen
# Runtime: 9.12 sec.
# Processing drug: obecabtagene autoleucel
# Runtime: 8.73 sec.
# Processing drug: obeticholic acid
# Runtime: 7.65 sec.
# Processing drug: obinutuzumab
# Runtime: 6.22 sec.
# Processing drug: ocrelizumab
# Runtime: 6.32 sec.
# Processing drug: octreotide
# Runtime: 6.65 sec.
# Processing drug: octreotide acetate
# Runtime: 6.58 sec.
# Processing drug: odevixibat
# Runtime: 5.80 sec.
# Processing drug: odronextamab
# Runtime: 6.12 sec.
# Processing drug: ofatumumab
# Runtime: 5.44 sec.
# Processing drug: ofloxacin
# Runtime: 5.38 sec.
# Processing drug: olanzapine
# Runtime: 5.52 sec.
# Processing drug: olaparib
# Runtime: 5.39 sec.
# Processing drug: olaratumab
# Runtime: 5.24 sec.
# Processing drug: olezarsen
# Runtime: 6.10 sec.
# Processing drug: oliceridine
# Runtime: 5.88 sec.
# Processing drug: olmesartan
# Runtime: 6.32 sec.
# Processing drug: olmesartan medoxomil
# Runtime: 5.56 sec.
# Processing drug: olmutinib
# Runtime: 9.40 sec.
# Processing drug: olodaterol
# Runtime: 11.43 sec.
# Processing drug: olodaterol hydrochloride
# Runtime: 10.34 sec.
# Processing drug: olopatadine
# Runtime: 9.59 sec.
# Processing drug: olsalazine
# Runtime: 10.27 sec.
# Processing drug: olutasidenib
# Runtime: 7.25 sec.
# Processing drug: omalizumab
# Runtime: 8.07 sec.
# Processing drug: omeprazole
# Runtime: 7.26 sec.
# Processing drug: omidenepag isopropyl
# Runtime: 6.93 sec.
# Processing drug: onapristone
# Runtime: 6.82 sec.
# Processing drug: ondansetron
# Runtime: 6.89 sec.
# Processing drug: opicapone
# Runtime: 6.73 sec.
# Processing drug: orciprenaline
# Runtime: 6.91 sec.
# Processing drug: orlistat
# 1500/2244 drugs processed
# Runtime: 6.71 sec.
# Processing drug: orphenadrine
# Runtime: 7.20 sec.
# Processing drug: oseltamivir
# Runtime: 7.02 sec.
# Processing drug: oseltamivir phosphate
# Runtime: 8.00 sec.
# Processing drug: osilodrostat
# Runtime: 6.26 sec.
# Processing drug: osimertinib
# Runtime: 6.69 sec.
# Processing drug: ospemifene
# Runtime: 7.15 sec.
# Processing drug: oteseconazole
# Runtime: 7.48 sec.
# Processing drug: ouabain
# Runtime: 6.32 sec.
# Processing drug: oxacillin
# Runtime: 6.23 sec.
# Processing drug: oxandrolone
# Runtime: 7.58 sec.
# Processing drug: oxaprozin
# Runtime: 7.16 sec.
# Processing drug: oxatomide
# Runtime: 7.74 sec.
# Processing drug: oxazepam
# Runtime: 7.28 sec.
# Processing drug: oxcarbazepine
# Runtime: 7.17 sec.
# Processing drug: oxiconazole
# Runtime: 7.81 sec.
# Processing drug: oxiconazole nitrate
# Runtime: 6.31 sec.
# Processing drug: oxitriptan
# Runtime: 5.38 sec.
# Processing drug: oxprenolol
# Runtime: 5.23 sec.
# Processing drug: oxtriphylline
# Runtime: 5.85 sec.
# Processing drug: oxybate
# Runtime: 5.87 sec.
# Processing drug: oxybuprocaine
# Runtime: 10.35 sec.
# Processing drug: oxybutynin
# Runtime: 8.27 sec.
# Processing drug: oxycodone
# Runtime: 10.06 sec.
# Processing drug: oxymetazoline
# Runtime: 8.43 sec.
# Processing drug: oxymetazoline hydrochloride
# Runtime: 6.67 sec.
# Processing drug: oxymetholone
# Runtime: 5.95 sec.
# Processing drug: oxymorphone
# Runtime: 7.33 sec.
# Processing drug: oxyphenbutazone anhydrous
# Runtime: 7.50 sec.
# Processing drug: oxyphencyclimine
# Runtime: 6.31 sec.
# Processing drug: oxyphenonium
# Runtime: 5.81 sec.
# Processing drug: oxypurinol
# Runtime: 7.06 sec.
# Processing drug: oxytocin
# Runtime: 6.93 sec.
# Processing drug: ozanimod
# Runtime: 5.71 sec.
# Processing drug: paclitaxel
# Runtime: 6.33 sec.
# Processing drug: pacritinib
# Runtime: 5.84 sec.
# Processing drug: pafolacianine
# Runtime: 6.28 sec.
# Processing drug: palbociclib
# Runtime: 6.84 sec.
# Processing drug: palifermin
# Runtime: 7.35 sec.
# Processing drug: paliperidone
# Runtime: 5.79 sec.
# Processing drug: palivizumab
# Runtime: 5.56 sec.
# Processing drug: palonosetron
# Runtime: 5.46 sec.
# Processing drug: palopegteriparatide
# Runtime: 5.45 sec.
# Processing drug: pamidronic acid
# Runtime: 5.60 sec.
# Processing drug: pancuronium
# Runtime: 5.67 sec.
# Processing drug: panitumumab
# Runtime: 5.17 sec.
# Processing drug: panobinostat
# Runtime: 5.56 sec.
# Processing drug: pantoprazole
# Runtime: 5.58 sec.
# Processing drug: papaverine
# Runtime: 5.28 sec.
# Processing drug: papaverine hydrochloride
# Runtime: 5.25 sec.
# Processing drug: paramethadione
# 1550/2244 drugs processed
# Runtime: 5.02 sec.
# Processing drug: parathyroid hormone
# Runtime: 5.18 sec.
# Processing drug: parecoxib
# Runtime: 5.22 sec.
# Processing drug: pargyline
# Runtime: 5.47 sec.
# Processing drug: paricalcitol
# Runtime: 5.18 sec.
# Processing drug: paromomycin
# Runtime: 5.39 sec.
# Processing drug: paroxetine
# Runtime: 5.33 sec.
# Processing drug: paroxetine hydrochloride
# Runtime: 5.27 sec.
# Processing drug: pasireotide
# Runtime: 5.47 sec.
# Processing drug: patent blue
# Runtime: 6.35 sec.
# Processing drug: pazopanib
# Runtime: 6.05 sec.
# Processing drug: peficitinib
# Runtime: 5.45 sec.
# Processing drug: pefloxacin
# Runtime: 5.00 sec.
# Processing drug: pegcetacoplan
# Runtime: 5.09 sec.
# Processing drug: pegfilgrastim
# Runtime: 5.17 sec.
# Processing drug: peginterferon alfa-2a
# Runtime: 5.15 sec.
# Processing drug: peginterferon alfa-2b
# Runtime: 5.20 sec.
# Processing drug: pegvisomant
# Runtime: 5.81 sec.
# Processing drug: pembrolizumab
# Runtime: 5.27 sec.
# Processing drug: pemetrexed
# Runtime: 5.47 sec.
# Processing drug: pemetrexed disodium
# Runtime: 4.86 sec.
# Processing drug: pemigatinib
# Runtime: 4.66 sec.
# Processing drug: pemoline
# Runtime: 4.84 sec.
# Processing drug: penicillamine
# Runtime: 5.02 sec.
# Processing drug: penicillin g potassium
# Runtime: 4.77 sec.
# Processing drug: penicillin v
# Runtime: 4.90 sec.
# Processing drug: pentagastrin
# Runtime: 4.84 sec.
# Processing drug: pentamidine
# Runtime: 5.19 sec.
# Processing drug: pentazocine
# Runtime: 5.49 sec.
# Processing drug: pentobarbital
# Runtime: 5.53 sec.
# Processing drug: pentolinium
# Runtime: 5.91 sec.
# Processing drug: pentosan polysulfate
# Runtime: 6.10 sec.
# Processing drug: pentostatin
# Runtime: 6.54 sec.
# Processing drug: pentoxifylline
# Runtime: 5.59 sec.
# Processing drug: peramivir anhydrous
# Runtime: 5.39 sec.
# Processing drug: perampanel
# Runtime: 4.94 sec.
# Processing drug: pergolide
# Runtime: 5.28 sec.
# Processing drug: perhexiline
# Runtime: 5.72 sec.
# Processing drug: perhexiline maleate
# Runtime: 5.81 sec.
# Processing drug: periciazine
# Runtime: 5.48 sec.
# Processing drug: perindopril
# Runtime: 5.36 sec.
# Processing drug: permethrin
# Runtime: 5.53 sec.
# Processing drug: perphenazine
# Runtime: 6.92 sec.
# Processing drug: pertuzumab
# Runtime: 6.49 sec.
# Processing drug: pexidartinib
# Runtime: 5.65 sec.
# Processing drug: phenacemide
# Runtime: 4.99 sec.
# Processing drug: phenazocine
# Runtime: 4.88 sec.
# Processing drug: phenazopyridine
# Runtime: 6.04 sec.
# Processing drug: phenazopyridine hydrochloride
# Runtime: 5.21 sec.
# Processing drug: phendimetrazine
# Runtime: 5.27 sec.
# Processing drug: phenelzine
# 1600/2244 drugs processed
# Runtime: 5.38 sec.
# Processing drug: phenformin
# Runtime: 5.82 sec.
# Processing drug: phenindamine
# Runtime: 7.40 sec.
# Processing drug: phenindione
# Runtime: 7.73 sec.
# Processing drug: pheniramine
# Runtime: 5.67 sec.
# Processing drug: phenobarbital
# Runtime: 4.89 sec.
# Processing drug: phenol
# Runtime: 5.01 sec.
# Processing drug: phenoxybenzamine
# Runtime: 4.89 sec.
# Processing drug: phenoxybenzamine hydrochloride
# Runtime: 5.00 sec.
# Processing drug: phenoxymethylpenicillin
# Runtime: 5.08 sec.
# Processing drug: phenprocoumon
# Runtime: 4.92 sec.
# Processing drug: phentermine
# Runtime: 4.81 sec.
# Processing drug: phentolamine
# Runtime: 4.80 sec.
# Processing drug: phenyl aminosalicylate
# Runtime: 4.98 sec.
# Processing drug: phenyl salicylate
# Runtime: 4.82 sec.
# Processing drug: phenylbutanoic acid
# Runtime: 4.98 sec.
# Processing drug: phenylbutazone
# Runtime: 4.86 sec.
# Processing drug: phenylephrine
# Runtime: 4.81 sec.
# Processing drug: phenylpropanolamine
# Runtime: 5.05 sec.
# Processing drug: phenytoin
# Runtime: 7.27 sec.
# Processing drug: phloroglucinol
# Runtime: 8.21 sec.
# Processing drug: phylloquinone
# Runtime: 6.97 sec.
# Processing drug: physostigmine
# Runtime: 6.42 sec.
# Processing drug: physostigmine salicylate
# Runtime: 7.14 sec.
# Processing drug: picotamide
# Runtime: 9.67 sec.
# Processing drug: piflufolastat
# Runtime: 9.10 sec.
# Processing drug: piflufolastat f 18
# Runtime: 6.86 sec.
# Processing drug: pilocarpine
# Runtime: 5.85 sec.
# Processing drug: pimavanserin
# Runtime: 5.92 sec.
# Processing drug: pimecrolimus
# Runtime: 6.61 sec.
# Processing drug: pimozide
# Runtime: 6.61 sec.
# Processing drug: pinacidil anhydrous
# Runtime: 6.67 sec.
# Processing drug: pinaverium
# Runtime: 6.39 sec.
# Processing drug: pindolol
# Runtime: 6.52 sec.
# Processing drug: pioglitazone
# Runtime: 6.71 sec.
# Processing drug: pioglitazone hydrochloride
# Runtime: 6.15 sec.
# Processing drug: piperacetazine
# Runtime: 6.28 sec.
# Processing drug: piperacillin
# Runtime: 6.48 sec.
# Processing drug: piperonyl butoxide
# Runtime: 7.63 sec.
# Processing drug: pirenzepine
# Runtime: 9.14 sec.
# Processing drug: piretanide
# Runtime: 8.95 sec.
# Processing drug: pirfenidone
# Runtime: 10.12 sec.
# Processing drug: piroxicam
# Runtime: 9.35 sec.
# Processing drug: pirtobrutinib
# Runtime: 8.60 sec.
# Processing drug: pitavastatin
# Runtime: 7.39 sec.
# Processing drug: pitavastatin calcium
# Runtime: 8.35 sec.
# Processing drug: pitolisant
# Runtime: 7.53 sec.
# Processing drug: pitolisant hydrochloride
# Runtime: 6.84 sec.
# Processing drug: plecanatide
# Runtime: 6.40 sec.
# Processing drug: plerixafor
# Runtime: 5.57 sec.
# Processing drug: plicamycin
# 1650/2244 drugs processed
# Runtime: 5.69 sec.
# Processing drug: podofilox
# Runtime: 5.71 sec.
# Processing drug: polatuzumab vedotin
# Runtime: 5.68 sec.
# Processing drug: polyestradiol phosphate
# Runtime: 5.51 sec.
# Processing drug: polymyxin b
# Runtime: 5.36 sec.
# Processing drug: polythiazide
# Runtime: 5.39 sec.
# Processing drug: pomalidomide
# Runtime: 5.34 sec.
# Processing drug: ponatinib
# Runtime: 5.76 sec.
# Processing drug: ponesimod
# Runtime: 5.80 sec.
# Processing drug: posaconazole
# Runtime: 5.62 sec.
# Processing drug: potassium bromide
# Runtime: 7.02 sec.
# Processing drug: potassium iodide
# Runtime: 5.31 sec.
# Processing drug: pozelimab
# Runtime: 5.27 sec.
# Processing drug: practolol
# Runtime: 5.30 sec.
# Processing drug: pralatrexate
# Runtime: 5.30 sec.
# Processing drug: pralidoxime
# Runtime: 5.26 sec.
# Processing drug: pralidoxime chloride
# Runtime: 5.43 sec.
# Processing drug: pralsetinib
# Runtime: 5.31 sec.
# Processing drug: pramipexole
# Runtime: 5.35 sec.
# Processing drug: pramipexole dihydrochloride
# Runtime: 5.37 sec.
# Processing drug: pramlintide
# Runtime: 5.35 sec.
# Processing drug: pramoxine
# Runtime: 5.34 sec.
# Processing drug: prasterone
# Runtime: 5.29 sec.
# Processing drug: prasugrel
# Runtime: 5.26 sec.
# Processing drug: pravastatin
# Runtime: 5.22 sec.
# Processing drug: pravastatin sodium
# Runtime: 5.23 sec.
# Processing drug: praziquantel
# Runtime: 5.67 sec.
# Processing drug: prazosin
# Runtime: 5.48 sec.
# Processing drug: prazosin hydrochloride
# Runtime: 5.82 sec.
# Processing drug: prednicarbate
# Runtime: 6.26 sec.
# Processing drug: prednisolone
# Runtime: 5.81 sec.
# Processing drug: prednisolone acetate
# Runtime: 7.68 sec.
# Processing drug: prednisolone phosphate
# Runtime: 7.58 sec.
# Processing drug: prednisone
# Runtime: 7.22 sec.
# Processing drug: pregabalin
# Runtime: 6.23 sec.
# Processing drug: prilocaine
# Runtime: 5.70 sec.
# Processing drug: primaquine
# Runtime: 5.52 sec.
# Processing drug: primidone
# Runtime: 7.53 sec.
# Processing drug: probenecid
# Runtime: 6.90 sec.
# Processing drug: probucol
# Runtime: 7.69 sec.
# Processing drug: procainamide
# Runtime: 9.40 sec.
# Processing drug: procaine
# Runtime: 8.06 sec.
# Processing drug: prochlorperazine
# Runtime: 6.83 sec.
# Processing drug: procyclidine
# Runtime: 6.61 sec.
# Processing drug: profenamine
# Runtime: 6.57 sec.
# Processing drug: progesterone
# Runtime: 6.71 sec.
# Processing drug: proglumide
# Runtime: 5.99 sec.
# Processing drug: proguanil
# Runtime: 7.09 sec.
# Processing drug: promazine
# Runtime: 8.03 sec.
# Processing drug: promethazine
# Runtime: 7.22 sec.
# Processing drug: propafenone
# 1700/2244 drugs processed
# Runtime: 7.73 sec.
# Processing drug: propantheline
# Runtime: 7.24 sec.
# Processing drug: propantheline bromide
# Runtime: 6.02 sec.
# Processing drug: proparacaine
# Runtime: 6.01 sec.
# Processing drug: propiomazine
# Runtime: 5.91 sec.
# Processing drug: propiverine
# Runtime: 5.92 sec.
# Processing drug: propofol
# Runtime: 6.30 sec.
# Processing drug: propoxycaine
# Runtime: 5.78 sec.
# Processing drug: propranolol
# Runtime: 6.08 sec.
# Processing drug: propranolol hydrochloride
# Runtime: 5.69 sec.
# Processing drug: propylhexedrine
# Runtime: 5.35 sec.
# Processing drug: propylthiouracil
# Runtime: 5.64 sec.
# Processing drug: protein c
# Runtime: 5.94 sec.
# Processing drug: protein s human
# Runtime: 6.16 sec.
# Processing drug: prothrombin
# Runtime: 5.99 sec.
# Processing drug: protirelin
# Runtime: 6.36 sec.
# Processing drug: protokylol
# Runtime: 6.85 sec.
# Processing drug: protriptyline
# Runtime: 7.12 sec.
# Processing drug: proxyphylline
# Runtime: 7.36 sec.
# Processing drug: prucalopride
# Runtime: 6.26 sec.
# Processing drug: pseudoephedrine
# Runtime: 6.21 sec.
# Processing drug: pyridostigmine
# Runtime: 5.92 sec.
# Processing drug: pyridostigmine bromide
# Runtime: 6.64 sec.
# Processing drug: pyrilamine
# Runtime: 6.56 sec.
# Processing drug: pyrimethamine
# Runtime: 6.08 sec.
# Processing drug: pyrithione zinc
# Runtime: 6.43 sec.
# Processing drug: pyrogallol
# Runtime: 5.40 sec.
# Processing drug: pyrvinium
# Runtime: 9.34 sec.
# Processing drug: quetiapine
# Runtime: 6.79 sec.
# Processing drug: quinapril
# Runtime: 6.02 sec.
# Processing drug: quinestrol
# Runtime: 5.23 sec.
# Processing drug: quinethazone
# Runtime: 5.21 sec.
# Processing drug: quinidine
# Runtime: 5.35 sec.
# Processing drug: quinidine barbiturate
# Runtime: 5.25 sec.
# Processing drug: quinidine sulfate
# Runtime: 5.10 sec.
# Processing drug: quinine
# Runtime: 5.75 sec.
# Processing drug: quizartinib
# Runtime: 5.64 sec.
# Processing drug: quizartinib dihydrochloride
# Runtime: 6.63 sec.
# Processing drug: rabeprazole
# Runtime: 5.90 sec.
# Processing drug: rabeprazole sodium
# Runtime: 5.58 sec.
# Processing drug: racecadotril
# Runtime: 6.49 sec.
# Processing drug: racepinephrine
# Runtime: 6.90 sec.
# Processing drug: raloxifene
# Runtime: 6.73 sec.
# Processing drug: raloxifene hydrochloride
# Runtime: 7.21 sec.
# Processing drug: raltegravir
# Runtime: 7.25 sec.
# Processing drug: raltitrexed
# Runtime: 5.33 sec.
# Processing drug: ramelteon
# Runtime: 5.12 sec.
# Processing drug: ramipril
# Runtime: 5.15 sec.
# Processing drug: ramucirumab
# Runtime: 5.19 sec.
# Processing drug: ranibizumab
# Runtime: 5.32 sec.
# Processing drug: ranitidine
# 1750/2244 drugs processed
# Runtime: 5.18 sec.
# Processing drug: ranolazine
# Runtime: 5.12 sec.
# Processing drug: rasagiline
# Runtime: 5.05 sec.
# Processing drug: rasagiline mesylate
# Runtime: 5.34 sec.
# Processing drug: rauwolfia serpentina
# Runtime: 5.19 sec.
# Processing drug: ravulizumab
# Runtime: 5.11 sec.
# Processing drug: reboxetine
# Runtime: 5.42 sec.
# Processing drug: regadenoson
# Runtime: 5.31 sec.
# Processing drug: regadenoson anhydrous
# Runtime: 6.28 sec.
# Processing drug: regorafenib
# Runtime: 5.25 sec.
# Processing drug: relatlimab
# Runtime: 5.64 sec.
# Processing drug: relugolix
# Runtime: 5.16 sec.
# Processing drug: remifentanil
# Runtime: 5.22 sec.
# Processing drug: remoxipride
# Runtime: 5.07 sec.
# Processing drug: repaglinide
# Runtime: 5.10 sec.
# Processing drug: repotrectinib
# Runtime: 5.24 sec.
# Processing drug: rescinnamine
# Runtime: 5.16 sec.
# Processing drug: reserpine
# Runtime: 5.48 sec.
# Processing drug: reslizumab
# Runtime: 5.96 sec.
# Processing drug: resmetirom
# Runtime: 7.19 sec.
# Processing drug: resorcinol
# Runtime: 6.06 sec.
# Processing drug: retifanlimab
# Runtime: 6.41 sec.
# Processing drug: revefenacin
# Runtime: 5.56 sec.
# Processing drug: revumenib
# Runtime: 6.31 sec.
# Processing drug: ribavirin
# Runtime: 5.88 sec.
# Processing drug: ribociclib
# Runtime: 5.77 sec.
# Processing drug: riboflavin 5'-phosphate
# Runtime: 7.00 sec.
# Processing drug: riboflavin 5'-phosphate sodium
# Runtime: 7.63 sec.
# Processing drug: rifabutin
# Runtime: 9.16 sec.
# Processing drug: rifampin
# Runtime: 7.88 sec.
# Processing drug: rifamycin
# Runtime: 7.74 sec.
# Processing drug: rifapentine
# Runtime: 7.25 sec.
# Processing drug: rifaximin
# Runtime: 6.90 sec.
# Processing drug: rilonacept
# Runtime: 7.49 sec.
# Processing drug: rilpivirine
# Runtime: 6.23 sec.
# Processing drug: riluzole
# Runtime: 5.65 sec.
# Processing drug: rimantadine
# Runtime: 5.77 sec.
# Processing drug: rimegepant
# Runtime: 5.62 sec.
# Processing drug: rimexolone
# Runtime: 5.70 sec.
# Processing drug: rimonabant
# Runtime: 5.76 sec.
# Processing drug: riociguat
# Runtime: 5.69 sec.
# Processing drug: ripretinib
# Runtime: 5.36 sec.
# Processing drug: risedronic acid
# Runtime: 5.49 sec.
# Processing drug: risperidone
# Runtime: 6.94 sec.
# Processing drug: ritlecitinib
# Runtime: 5.92 sec.
# Processing drug: ritodrine
# Runtime: 7.74 sec.
# Processing drug: ritonavir
# Runtime: 8.40 sec.
# Processing drug: rituximab
# Runtime: 7.66 sec.
# Processing drug: rivaroxaban
# Runtime: 5.41 sec.
# Processing drug: rivastigmine
# Runtime: 6.59 sec.
# Processing drug: rivastigmine tartrate
# 1800/2244 drugs processed
# Runtime: 7.17 sec.
# Processing drug: rizatriptan
# Runtime: 7.01 sec.
# Processing drug: rociletinib
# Runtime: 6.63 sec.
# Processing drug: rocuronium
# Runtime: 6.66 sec.
# Processing drug: rofecoxib
# Runtime: 5.70 sec.
# Processing drug: roflumilast
# Runtime: 7.98 sec.
# Processing drug: rolapitant
# Runtime: 7.38 sec.
# Processing drug: romidepsin
# Runtime: 7.46 sec.
# Processing drug: romiplostim
# Runtime: 7.21 sec.
# Processing drug: romosozumab
# Runtime: 6.20 sec.
# Processing drug: ropinirole
# Runtime: 5.88 sec.
# Processing drug: ropivacaine
# Runtime: 5.97 sec.
# Processing drug: rosiglitazone
# Runtime: 7.26 sec.
# Processing drug: rosiglitazone maleate
# Runtime: 6.66 sec.
# Processing drug: rosuvastatin
# Runtime: 7.66 sec.
# Processing drug: rosuvastatin calcium
# Runtime: 7.16 sec.
# Processing drug: rotigotine
# Runtime: 6.18 sec.
# Processing drug: roxadustat
# Runtime: 5.91 sec.
# Processing drug: rozanolixizumab
# Runtime: 6.08 sec.
# Processing drug: rucaparib
# Runtime: 5.94 sec.
# Processing drug: rufinamide
# Runtime: 7.70 sec.
# Processing drug: rupatadine
# Runtime: 7.46 sec.
# Processing drug: rurioctocog alfa pegol
# Runtime: 7.25 sec.
# Processing drug: rutin
# Runtime: 6.09 sec.
# Processing drug: ruxolitinib
# Runtime: 5.67 sec.
# Processing drug: ruxolitinib phosphate
# Runtime: 7.18 sec.
# Processing drug: sacituzumab govitecan
# Runtime: 7.46 sec.
# Processing drug: sacubitril
# Runtime: 5.47 sec.
# Processing drug: safinamide
# Runtime: 5.33 sec.
# Processing drug: salicylic acid
# Runtime: 5.12 sec.
# Processing drug: salmeterol
# Runtime: 5.14 sec.
# Processing drug: salmeterol xinafoate
# Runtime: 5.65 sec.
# Processing drug: salmon calcitonin
# Runtime: 6.05 sec.
# Processing drug: salsalate
# Runtime: 7.77 sec.
# Processing drug: samidorphan
# Runtime: 6.73 sec.
# Processing drug: sapropterin
# Runtime: 5.17 sec.
# Processing drug: saquinavir
# Runtime: 5.20 sec.
# Processing drug: saralasin
# Runtime: 5.18 sec.
# Processing drug: sargramostim
# Runtime: 5.11 sec.
# Processing drug: sarilumab
# Runtime: 5.21 sec.
# Processing drug: satralizumab
# Runtime: 5.25 sec.
# Processing drug: saxagliptin
# Runtime: 5.56 sec.
# Processing drug: saxagliptin anhydrous
# Runtime: 5.26 sec.
# Processing drug: scopolamine
# Runtime: 5.14 sec.
# Processing drug: secobarbital
# Runtime: 6.25 sec.
# Processing drug: secretin
# Runtime: 5.79 sec.
# Processing drug: secretin human
# Runtime: 5.20 sec.
# Processing drug: secukinumab
# Runtime: 5.16 sec.
# Processing drug: segesterone acetate
# Runtime: 5.31 sec.
# Processing drug: seladelpar
# Runtime: 5.06 sec.
# Processing drug: selegiline
# 1850/2244 drugs processed
# Runtime: 6.73 sec.
# Processing drug: selegiline hydrochloride
# Runtime: 6.06 sec.
# Processing drug: selexipag
# Runtime: 6.07 sec.
# Processing drug: selinexor
# Runtime: 5.98 sec.
# Processing drug: selpercatinib
# Runtime: 6.80 sec.
# Processing drug: selumetinib
# Runtime: 6.75 sec.
# Processing drug: semaglutide
# Runtime: 5.82 sec.
# Processing drug: sennosides
# Runtime: 6.25 sec.
# Processing drug: seractide acetate
# Runtime: 5.76 sec.
# Processing drug: serdexmethylphenidate
# Runtime: 5.66 sec.
# Processing drug: sertaconazole
# Runtime: 5.72 sec.
# Processing drug: sertindole
# Runtime: 5.51 sec.
# Processing drug: sertraline
# Runtime: 7.06 sec.
# Processing drug: setmelanotide
# Runtime: 8.74 sec.
# Processing drug: sevoflurane
# Runtime: 7.90 sec.
# Processing drug: sibutramine
# Runtime: 7.08 sec.
# Processing drug: sildenafil
# Runtime: 6.51 sec.
# Processing drug: sildenafil citrate
# Runtime: 6.44 sec.
# Processing drug: silodosin
# Runtime: 6.16 sec.
# Processing drug: siltuximab
# Runtime: 5.79 sec.
# Processing drug: simeprevir
# Runtime: 5.81 sec.
# Processing drug: simoctocog alfa
# Runtime: 6.32 sec.
# Processing drug: simvastatin
# Runtime: 6.43 sec.
# Processing drug: siponimod
# Runtime: 6.15 sec.
# Processing drug: sipuleucel-t
# Runtime: 6.38 sec.
# Processing drug: sirolimus
# Runtime: 6.05 sec.
# Processing drug: sitagliptin
# Runtime: 5.76 sec.
# Processing drug: sitaxentan
# Runtime: 5.70 sec.
# Processing drug: sodium benzoate
# Runtime: 5.94 sec.
# Processing drug: sodium bromide
# Runtime: 6.16 sec.
# Processing drug: sodium ferric gluconate complex
# Runtime: 5.44 sec.
# Processing drug: sodium phenylbutyrate
# Runtime: 6.39 sec.
# Processing drug: sodium phosphate
# Runtime: 5.79 sec.
# Processing drug: sodium stibogluconate
# Runtime: 5.57 sec.
# Processing drug: sodium sulfate
# Runtime: 6.63 sec.
# Processing drug: sodium tetradecyl sulfate
# Runtime: 7.86 sec.
# Processing drug: sofosbuvir
# Runtime: 7.01 sec.
# Processing drug: sofpironium
# Runtime: 6.08 sec.
# Processing drug: solifenacin
# Runtime: 5.81 sec.
# Processing drug: solifenacin succinate
# Runtime: 6.38 sec.
# Processing drug: somapacitan
# Runtime: 6.36 sec.
# Processing drug: somatotropin
# Runtime: 5.86 sec.
# Processing drug: somatrogon
# Runtime: 7.01 sec.
# Processing drug: sonidegib
# Runtime: 7.50 sec.
# Processing drug: sorafenib
# Runtime: 7.71 sec.
# Processing drug: sorafenib tosylate
# Runtime: 8.70 sec.
# Processing drug: sotagliflozin
# Runtime: 7.60 sec.
# Processing drug: sotalol
# Runtime: 7.09 sec.
# Processing drug: sotalol hydrochloride
# Runtime: 6.73 sec.
# Processing drug: sotatercept
# Runtime: 6.49 sec.
# Processing drug: sotorasib
# 1900/2244 drugs processed
# Runtime: 6.09 sec.
# Processing drug: soybean oil
# Runtime: 5.30 sec.
# Processing drug: sparfloxacin
# Runtime: 5.67 sec.
# Processing drug: sparsentan
# Runtime: 5.59 sec.
# Processing drug: spinosad
# Runtime: 5.65 sec.
# Processing drug: spirapril
# Runtime: 6.11 sec.
# Processing drug: spirapril hydrochloride
# Runtime: 6.10 sec.
# Processing drug: spironolactone
# Runtime: 5.38 sec.
# Processing drug: stanozolol
# Runtime: 5.62 sec.
# Processing drug: stavudine
# Runtime: 6.16 sec.
# Processing drug: stiripentol
# Runtime: 6.65 sec.
# Processing drug: streptomycin
# Runtime: 7.64 sec.
# Processing drug: sucralfate
# Runtime: 5.80 sec.
# Processing drug: sucrose
# Runtime: 5.88 sec.
# Processing drug: sufentanil
# Runtime: 5.65 sec.
# Processing drug: sulconazole
# Runtime: 5.62 sec.
# Processing drug: sulconazole nitrate
# Runtime: 5.96 sec.
# Processing drug: sulfacetamide
# Runtime: 5.07 sec.
# Processing drug: sulfadiazine
# Runtime: 5.23 sec.
# Processing drug: sulfadimethoxine
# Runtime: 5.52 sec.
# Processing drug: sulfaguanidine
# Runtime: 5.28 sec.
# Processing drug: sulfamethizole
# Runtime: 5.17 sec.
# Processing drug: sulfanilamide
# Runtime: 5.25 sec.
# Processing drug: sulfaphenazole
# Runtime: 5.11 sec.
# Processing drug: sulfasalazine
# Runtime: 5.15 sec.
# Processing drug: sulfathiazole
# Runtime: 5.05 sec.
# Processing drug: sulfinpyrazone
# Runtime: 5.27 sec.
# Processing drug: sulfisoxazole
# Runtime: 5.41 sec.
# Processing drug: sulindac
# Runtime: 6.49 sec.
# Processing drug: sulpiride
# Runtime: 5.53 sec.
# Processing drug: sulthiame
# Runtime: 6.03 sec.
# Processing drug: sumatriptan
# Runtime: 7.00 sec.
# Processing drug: sunitinib
# Runtime: 6.93 sec.
# Processing drug: sunitinib malate
# Runtime: 5.70 sec.
# Processing drug: suprofen
# Runtime: 5.66 sec.
# Processing drug: susoctocog alfa
# Runtime: 5.47 sec.
# Processing drug: suvorexant
# Runtime: 5.74 sec.
# Processing drug: suzetrigine
# Runtime: 6.08 sec.
# Processing drug: synthetic conjugated estrogens, a
# Runtime: 7.09 sec.
# Processing drug: synthetic conjugated estrogens, b
# Runtime: 5.63 sec.
# Processing drug: tacalcitol
# Runtime: 5.90 sec.
# Processing drug: tacrine
# Runtime: 5.46 sec.
# Processing drug: tacrine hydrochloride
# Runtime: 5.61 sec.
# Processing drug: tacrolimus
# Runtime: 5.27 sec.
# Processing drug: tacrolimus anhydrous
# Runtime: 5.82 sec.
# Processing drug: tadalafil
# Runtime: 5.64 sec.
# Processing drug: tafamidis
# Runtime: 6.65 sec.
# Processing drug: tafasitamab
# Runtime: 5.69 sec.
# Processing drug: tafluprost
# Runtime: 6.87 sec.
# Processing drug: tagraxofusp
# Runtime: 6.99 sec.
# Processing drug: talazoparib
# 1950/2244 drugs processed
# Runtime: 5.68 sec.
# Processing drug: talimogene laherparepvec
# Runtime: 6.51 sec.
# Processing drug: talquetamab
# Runtime: 5.55 sec.
# Processing drug: tamoxifen
# Runtime: 5.52 sec.
# Processing drug: tamoxifen citrate
# Runtime: 5.45 sec.
# ...
# Runtime: 6.23 sec.
# Processing drug: thymol
# Runtime: 7.05 sec.
# Processing drug: thyroid, porcine
# Runtime: 7.04 sec.
# Processing drug: thyrotropin alfa
# Runtime: 6.53 sec.
# Processing drug: tiagabine
# Runtime: 7.66 sec.
# Processing drug: tiagabine hydrochloride
# Runtime: 7.01 sec.
# Processing drug: tiaprofenic acid
# Runtime: 7.24 sec.
# Processing drug: tibolone
# Runtime: 6.66 sec.
# Processing drug: ticagrelor
# Runtime: 6.70 sec.
# Processing drug: ticlopidine
# Runtime: 6.97 sec.
# Processing drug: tiludronate disodium
# Runtime: 6.37 sec.
# Processing drug: tiludronic acid
# Runtime: 6.83 sec.
# Processing drug: timolol
# Runtime: 6.27 sec.
# Processing drug: tinzaparin
# Runtime: 6.74 sec.
# Processing drug: tioconazole
# Runtime: 5.90 sec.
# Processing drug: tiotropium
# Runtime: 6.15 sec.
# Processing drug: tiotropium bromide
# 2050/2244 drugs processed
# Runtime: 6.56 sec.
# Processing drug: tipiracil
# Runtime: 6.08 sec.
# Processing drug: tipiracil hydrochloride
# Runtime: 6.46 sec.
# Processing drug: tipranavir
# Runtime: 6.21 sec.
# Processing drug: tirbanibulin
# Runtime: 6.18 sec.
# Processing drug: tirofiban
# Runtime: 6.66 sec.
# Processing drug: tirzepatide
# Runtime: 6.04 sec.
# Processing drug: tisagenlecleucel
# Runtime: 9.16 sec.
# Processing drug: tislelizumab
# Runtime: 7.01 sec.
# Processing drug: tisotumab vedotin
# Runtime: 6.99 sec.
# Processing drug: tivozanib
# Runtime: 7.00 sec.
# Processing drug: tizanidine
# Runtime: 7.36 sec.
# Processing drug: tizanidine hydrochloride
# Runtime: 7.45 sec.
# Processing drug: tocilizumab
# Runtime: 7.33 sec.
# Processing drug: tocofersolan
# Runtime: 7.06 sec.
# Processing drug: tofacitinib
# Runtime: 6.64 sec.
# Processing drug: tofacitinib citrate
# Runtime: 5.47 sec.
# Processing drug: tolazamide
# Runtime: 5.97 sec.
# Processing drug: tolazoline
# Runtime: 7.39 sec.
# Processing drug: tolazoline hydrochloride
# Runtime: 6.35 sec.
# Processing drug: tolbutamide
# Runtime: 6.71 sec.
# Processing drug: tolcapone
# Runtime: 6.01 sec.
# Processing drug: tolfenamic acid
# Runtime: 6.29 sec.
# Processing drug: tolmetin
# Runtime: 6.39 sec.
# Processing drug: tolnaftate
# Runtime: 8.79 sec.
# Processing drug: tolrestat
# Runtime: 7.22 sec.
# Processing drug: tolterodine
# Runtime: 6.88 sec.
# Processing drug: tolvaptan
# Runtime: 7.04 sec.
# Processing drug: topiramate
# Runtime: 7.04 sec.
# Processing drug: topotecan
# Runtime: 6.37 sec.
# Processing drug: topotecan hydrochloride
# Runtime: 5.83 sec.
# Processing drug: torasemide
# Runtime: 5.94 sec.
# Processing drug: toremifene
# Runtime: 7.57 sec.
# Processing drug: toremifene citrate
# Runtime: 6.71 sec.
# Processing drug: toripalimab
# Runtime: 5.94 sec.
# Processing drug: torsemide
# Runtime: 5.95 sec.
# Processing drug: tovorafenib
# Runtime: 6.04 sec.
# Processing drug: tramadol
# Runtime: 6.38 sec.
# Processing drug: trametinib
# Runtime: 6.64 sec.
# Processing drug: trandolapril
# Runtime: 5.82 sec.
# Processing drug: tranexamic acid
# Runtime: 7.08 sec.
# Processing drug: tranylcypromine
# Runtime: 7.15 sec.
# Processing drug: trastuzumab
# Runtime: 7.78 sec.
# Processing drug: trastuzumab deruxtecan
# Runtime: 5.45 sec.
# Processing drug: trastuzumab emtansine
# Runtime: 5.60 sec.
# Processing drug: travoprost
# Runtime: 5.74 sec.
# Processing drug: trazodone
# Runtime: 5.96 sec.
# Processing drug: trazodone hydrochloride
# Runtime: 6.14 sec.
# Processing drug: tremelimumab
# Runtime: 6.43 sec.
# Processing drug: treprostinil
# Runtime: 6.58 sec.
# Processing drug: tretinoin
# 2100/2244 drugs processed
# Runtime: 8.11 sec.
# Processing drug: triamcinolone
# Runtime: 10.02 sec.
# Processing drug: triamcinolone acetonide
# Runtime: 8.34 sec.
# Processing drug: triamterene
# Runtime: 6.95 sec.
# Processing drug: triazolam
# Runtime: 6.58 sec.
# Processing drug: trichlormethiazide
# Runtime: 7.02 sec.
# Processing drug: triclabendazole
# Runtime: 6.29 sec.
# Processing drug: triclocarban
# Runtime: 5.85 sec.
# Processing drug: triclosan
# Runtime: 5.96 sec.
# Processing drug: trientine
# Runtime: 6.56 sec.
# Processing drug: trifarotene
# Runtime: 10.89 sec.
# Processing drug: trifluoperazine
# Runtime: 9.04 sec.
# Processing drug: trifluperidol
# Runtime: 9.11 sec.
# Processing drug: triflupromazine
# Runtime: 8.69 sec.
# Processing drug: triflupromazine hydrochloride
# Runtime: 7.69 sec.
# Processing drug: trifluridine
# Runtime: 6.80 sec.
# Processing drug: trihexyphenidyl
# Runtime: 7.09 sec.
# Processing drug: trihexyphenidyl hydrochloride
# Runtime: 7.07 sec.
# Processing drug: trilaciclib
# Runtime: 5.77 sec.
# Processing drug: trimebutine
# Runtime: 5.47 sec.
# Processing drug: trimethaphan
# Runtime: 6.21 sec.
# Processing drug: trimethobenzamide
# Runtime: 6.05 sec.
# Processing drug: trimethoprim
# Runtime: 5.07 sec.
# Processing drug: trimetrexate
# Runtime: 5.43 sec.
# Processing drug: trimipramine
# Runtime: 5.05 sec.
# Processing drug: trioxsalen
# Runtime: 6.59 sec.
# Processing drug: tripelennamine
# Runtime: 5.60 sec.
# Processing drug: triprolidine
# Runtime: 7.17 sec.
# Processing drug: triptorelin
# Runtime: 6.89 sec.
# Processing drug: troglitazone
# Runtime: 5.71 sec.
# Processing drug: trolamine salicylate
# Runtime: 5.47 sec.
# Processing drug: troleandomycin
# Runtime: 5.77 sec.
# Processing drug: tropicamide
# Runtime: 5.69 sec.
# Processing drug: tropisetron
# Runtime: 6.00 sec.
# Processing drug: trospium chloride
# Runtime: 5.41 sec.
# Processing drug: trovafloxacin
# Runtime: 5.82 sec.
# Processing drug: tryptophan
# Runtime: 5.62 sec.
# Processing drug: tuberculin purified protein derivative
# Runtime: 5.55 sec.
# Processing drug: tubocurarine
# Runtime: 5.76 sec.
# Processing drug: tucatinib
# Runtime: 5.36 sec.
# Processing drug: tulobuterol
# Runtime: 5.02 sec.
# Processing drug: turoctocog alfa
# Runtime: 5.31 sec.
# Processing drug: turoctocog alfa pegol
# Runtime: 5.28 sec.
# Processing drug: tyloxapol
# Runtime: 5.80 sec.
# Processing drug: ublituximab
# Runtime: 5.68 sec.
# Processing drug: ubrogepant
# Runtime: 5.04 sec.
# Processing drug: udenafil
# Runtime: 5.23 sec.
# Processing drug: ulipristal
# Runtime: 6.18 sec.
# Processing drug: ulipristal acetate
# Runtime: 7.06 sec.
# Processing drug: ulobetasol
# Runtime: 5.73 sec.
# Processing drug: umbralisib
# 2150/2244 drugs processed
# Runtime: 5.28 sec.
# Processing drug: umeclidinium
# Runtime: 4.96 sec.
# Processing drug: umeclidinium bromide
# Runtime: 4.92 sec.
# Processing drug: upadacitinib
# Runtime: 4.90 sec.
# Processing drug: urea
# Runtime: 4.85 sec.
# Processing drug: ursodeoxycholic acid
# Runtime: 4.85 sec.
# Processing drug: ursodiol
# Runtime: 4.87 sec.
# Processing drug: ustekinumab
# Runtime: 4.80 sec.
# Processing drug: vaborbactam
# Runtime: 4.98 sec.
# Processing drug: vadadustat
# Runtime: 4.97 sec.
# Processing drug: valacyclovir
# Runtime: 4.93 sec.
# Processing drug: valbenazine
# Runtime: 5.24 sec.
# Processing drug: valdecoxib
# Runtime: 6.07 sec.
# Processing drug: valproic acid
# Runtime: 4.95 sec.
# Processing drug: valrubicin
# Runtime: 4.78 sec.
# Processing drug: valsartan
# Runtime: 4.86 sec.
# Processing drug: vancomycin
# Runtime: 4.69 sec.
# Processing drug: vandetanib
# Runtime: 5.02 sec.
# Processing drug: vanzacaftor
# Runtime: 4.84 sec.
# Processing drug: vardenafil
# Runtime: 5.08 sec.
# Processing drug: vardenafil hydrochloride
# Runtime: 4.91 sec.
# Processing drug: varenicline
# Runtime: 5.04 sec.
# Processing drug: vasopressin
# Runtime: 5.01 sec.
# Processing drug: vecuronium
# Runtime: 7.95 sec.
# Processing drug: vecuronium bromide
# Runtime: 6.57 sec.
# Processing drug: vedolizumab
# Runtime: 6.41 sec.
# Processing drug: velaglucerase alfa
# Runtime: 10.09 sec.
# Processing drug: vemurafenib
# Runtime: 9.80 sec.
# Processing drug: venetoclax
# Runtime: 10.23 sec.
# Processing drug: venlafaxine
# Runtime: 7.29 sec.
# Processing drug: venlafaxine hydrochloride
# Runtime: 6.50 sec.
# Processing drug: verapamil
# Runtime: 6.09 sec.
# Processing drug: verapamil hydrochloride
# Runtime: 6.35 sec.
# Processing drug: vericiguat
# Runtime: 7.64 sec.
# Processing drug: vernakalant
# Runtime: 6.38 sec.
# Processing drug: vernakalant hydrochloride
# Runtime: 6.44 sec.
# Processing drug: verteporfin
# Runtime: 5.84 sec.
# Processing drug: vibegron
# Runtime: 5.29 sec.
# Processing drug: vidarabine
# Runtime: 5.45 sec.
# Processing drug: vigabatrin
# Runtime: 5.55 sec.
# Processing drug: vilazodone
# Runtime: 7.70 sec.
# Processing drug: vilazodone hydrochloride
# Runtime: 6.13 sec.
# Processing drug: vildagliptin
# Runtime: 5.83 sec.
# Processing drug: viloxazine
# Runtime: 7.23 sec.
# Processing drug: vinblastine
# Runtime: 6.31 sec.
# Processing drug: vinblastine sulfate
# Runtime: 7.24 sec.
# Processing drug: vincristine
# Runtime: 6.47 sec.
# Processing drug: vinflunine
# Runtime: 5.94 sec.
# Processing drug: vinorelbine
# Runtime: 8.53 sec.
# Processing drug: vinpocetine
# Runtime: 7.69 sec.
# Processing drug: vismodegib
# 2200/2244 drugs processed
# Runtime: 6.67 sec.
# Processing drug: voclosporin
# Runtime: 6.16 sec.
# Processing drug: volanesorsen
# Runtime: 5.87 sec.
# Processing drug: von willebrand factor human
# Runtime: 5.76 sec.
# Processing drug: vonicog alfa
# Runtime: 6.03 sec.
# Processing drug: vorapaxar
# Runtime: 6.57 sec.
# Processing drug: vorasidenib
# Runtime: 6.71 sec.
# Processing drug: voretigene neparvovec
# Runtime: 6.02 sec.
# Processing drug: voriconazole
# Runtime: 7.19 sec.
# Processing drug: vorinostat
# Runtime: 5.51 sec.
# Processing drug: vortioxetine
# Runtime: 5.51 sec.
# Processing drug: vosoritide
# Runtime: 5.37 sec.
# Processing drug: voxelotor
# Runtime: 5.59 sec.
# Processing drug: warfarin
# Runtime: 5.51 sec.
# Processing drug: xamoterol
# Runtime: 5.86 sec.
# Processing drug: xamoterol fumarate
# Runtime: 5.58 sec.
# Processing drug: xanomeline
# Runtime: 7.30 sec.
# Processing drug: xylometazoline
# Runtime: 6.79 sec.
# Processing drug: xylometazoline hydrochloride
# Runtime: 5.41 sec.
# Processing drug: yohimbine
# Runtime: 5.91 sec.
# Processing drug: yohimbine hydrochloride
# Runtime: 5.35 sec.
# Processing drug: zafirlukast
# Runtime: 5.52 sec.
# Processing drug: zalcitabine
# Runtime: 5.59 sec.
# Processing drug: zaleplon
# Runtime: 5.30 sec.
# Processing drug: zanamivir
# Runtime: 5.88 sec.
# Processing drug: zanidatamab
# Runtime: 5.66 sec.
# Processing drug: zanubrutinib
# Runtime: 5.76 sec.
# Processing drug: zavegepant
# Runtime: 6.25 sec.
# Processing drug: zenocutuzumab
# Runtime: 7.12 sec.
# Processing drug: ziconotide
# Runtime: 5.69 sec.
# Processing drug: zidovudine
# Runtime: 5.36 sec.
# Processing drug: zileuton
# Runtime: 5.94 sec.
# Processing drug: zilucoplan
# Runtime: 5.10 sec.
# Processing drug: ziprasidone
# Runtime: 5.05 sec.
# Processing drug: zofenopril
# Runtime: 5.16 sec.
# Processing drug: zolbetuximab
# Runtime: 5.29 sec.
# Processing drug: zoledronic acid
# Runtime: 5.59 sec.
# Processing drug: zolmitriptan
# Runtime: 5.76 sec.
# Processing drug: zolpidem
# Runtime: 5.18 sec.
# Processing drug: zonisamide
# Runtime: 5.11 sec.
# Processing drug: zopiclone
# Runtime: 5.80 sec.
# Processing drug: zotepine
# Runtime: 5.81 sec.
# Processing drug: zuclopenthixol
# Runtime: 5.20 sec.
# Processing drug: zuranolone
# Runtime: 5.28 sec.
# Saved results to ../results/humanPVATsn/network_analysis/proximity_step1_key_only.csv
# Top 10 prioritised drugs for step1                             drug  distance    z_score
# 1131                   lecanemab  0.000000 -11.806254
# 836              florbetaben f18  0.000000 -11.806254
# 835             florbetaben f-18  0.000000 -11.806254
# 39                    aducanumab  0.000000 -11.806254
# 867           flutemetamol (18f)  0.000000 -11.806254
# 1635  pioglitazone hydrochloride  0.500000  -7.680816
# 1243                  mecasermin  0.500000  -7.680816
# 1813       rosiglitazone maleate  0.666667  -6.305670
# 691                  elafibranor  0.666667  -6.305670
# 990              hyaluronic acid  0.750000  -5.618097
#
# ===== Processing step2 =====
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 23
#      21 # Run proximity analysis for each step
#      22 for step, path in steps.items():
# ---> 23     run_proximity_analysis(step_name=step,
#      24                            deg_file_path=path["deg_file"],
#      25                            output_csv_path=path["output_csv"],
#      26                            ppi_graph=ppi_graph,
#      27                            drug_to_targets=drug_to_targets,
#      28                            bins=bins,
#      29                            n_random=100,
#      30                            min_bin_size=100,
#      31                            seed=452456)
#
# Cell In[6], line 10, in run_proximity_analysis(step_name, deg_file_path, output_csv_path, ppi_graph, drug_to_targets, bins, n_random, min_bin_size, seed)
#       7 print(f"\n===== Processing {step_name} =====")
#       9 # ========== LOAD DISEASE GENES ==========
# ---> 10 disease_genes = pd.read_csv(deg_file_path, header=None)
#      11 print(len(disease_genes), f"disease genes in {step_name}")
#      12 disease_genes = disease_genes.iloc[:,0].dropna().unique().tolist()
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.../results/humanPVATsn/network_analysis/step2_key_genes_only.csv'

# %%
path2 = steps["step2"]
run_proximity_analysis(step_name=step,
                           deg_file_path=path2["deg_file"],
                           output_csv_path=path2["output_csv"],
                           ppi_graph=ppi_graph,
                           drug_to_targets=drug_to_targets,
                           bins=bins,
                           n_random=100,
                           min_bin_size=100,
                           seed=452456)

# %%
path3 = steps["step3"]
run_proximity_analysis(step_name=step,
                           deg_file_path=path3["deg_file"],
                           output_csv_path=path3["output_csv"],
                           ppi_graph=ppi_graph,
                           drug_to_targets=drug_to_targets,
                           bins=bins,
                           n_random=100,
                           min_bin_size=100,
                           seed=452456)

# %%
path_full = steps["full"]
run_proximity_analysis(step_name=step,
                           deg_file_path=path_full["deg_file"],
                           output_csv_path=path_full["output_csv"],
                           ppi_graph=ppi_graph,
                           drug_to_targets=drug_to_targets,
                           bins=bins,
                           n_random=100,
                           min_bin_size=100,
                           seed=452456)
