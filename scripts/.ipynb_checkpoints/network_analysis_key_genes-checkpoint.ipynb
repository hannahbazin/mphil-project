# %% [markdown]
# # Network analysis
#
# This generates the three inputs for network analysis and calls the algorithm. This script only runs the analysis on the key genes rather than the whole differentially expressed gene list, in the interest of time.

# %%
import pandas as pd

# %% [markdown]
# # Drug proximity analysis

# %% [markdown]
# ## Define functions
# The code from this chunk is taken from a paper by Han et al. (2021) titled "Identification of SARS-CoV-2–induced pathways reveals drug repurposing strategies".

# %%
# functions
def has_path(G,node_from,node_to): # returns true if the graph G has a path from source node(node_from) to target node (node_to)
    return(nx.has_path(G,node_from,node_to))


def get_shortest_path_length_between(G, source_id, target_id): #calculates shortest path length between source and target nodes in the graph G
    return nx.shortest_path_length(G, source_id, target_id) 

'''
The function below uses the previous two functions to calculate the path length 
between each source node (drug target) and its closest disease target.
See Guney 2015 for more details on the approach (Network-based in silico drug efficacy screening).
'''
def calculate_closest_distance(network, nodes_from, nodes_to):
    values_outer = []
    for node_from in nodes_from: #nodes_from is a list of drug targets (eg. from drugbank, chembl, etc.)
        values = [] # will store the shortest path length between a source node and all disease targets here
        for node_to in nodes_to: #nodes_to is a list of known disease targets
            # print("from - to", node_from, node_to)
            if not has_path(network,node_from,node_to): continue
            val = get_shortest_path_length_between(network, node_from, node_to)
            values.append(val)
        if len(values) == 0:    continue
        d = min(values) # the shortest path between a source node and its closest disease target
        # print (d)
        values_outer.append(d)
    closest_d = numpy.mean(values_outer) # the average shortest path length between any source node (drug target) and its closest disease target
    # print (d)
    return closest_d


def get_degree_binning(g, bin_size):
    '''
    This function creates the bins from a network g.
    Starting from a list of nodes with the lowest degree, it adds nodes with the same degree to the bin until it reaches the set bin size.
    If number of nodes with some degree is lower then bin size, it combines with other nodes with degree + 1 to meet bin size.
    '''
    degree_to_nodes = {}
    # the below two lines compute the degree of each node in the graph.
    # the setdefault method is used to add each node to a list of nodes with the same degree in the dictionary
    for node, degree in g.degree(): 
        degree_to_nodes.setdefault(degree, []).append(node)
    values = degree_to_nodes.keys()
    values = sorted(values) # values becomes a list, sorted from lowest to highest degree
    bins = []
    i = 0 # this is the iterator that iterates over each degree, starting from the first item in the list (lowest degree)
    while i < len(values):
        low = values[i] # this is the i-th degree in the values list
        val = degree_to_nodes[values[i]] # a list of the nodes with i-th degree (low)
        while len(val) < bin_size:
            # while the number of nodes in a bin is lower than the bin size, than nodes with degree i+1 will be added to the bin
            # bin size is chosen by the user - in the paper this is set to 100
            i += 1 # next iteration (move to the next degree in the list)
            if i == len(values): # breaks when the last item in the list is reached
                break
            # starting from a list of nodes with the lowest degree, it adds nodes with degree lowest + 1 to the val list until it reaches the set bin size
            val.extend(degree_to_nodes[values[i]]) # val will be extended with the next set of nodes with degree i+1 (low +1).
        if i == len(values):
            i -= 1
        high = values[i] # this is the highest degree
        i += 1
        # print i, low, high, len(val)
        if len(val) < bin_size:
            low_, high_, val_ = bins[-1]
            bins[-1] = (low_, high, val_ + val)
        else:
            bins.append((low, high, val))
    return bins

# this function lists all nodes in the same bin as each seed node
def get_degree_equivalents(seeds, bins, g): 
    seed_to_nodes = {}
    for seed in seeds:
        d = g.degree(seed) #extract degree of the seed node
        for l, h, nodes in bins: #it takes low, high degree and nodes for each bin
            if l <= d and h >= d:
                mod_nodes = list(nodes)
                mod_nodes.remove(seed)
                seed_to_nodes[seed] = mod_nodes
                break
    return seed_to_nodes

    
def pick_random_nodes_matching_selected(network, bins, nodes_selected, n_random, degree_aware=True, connected=False,
                                        seed=None):
    """
    Use get_degree_binning to get bins
    """
    if seed is not None:
        random.seed(seed)
    values = []
    nodes = network.nodes() # list of nodes in the network
    for i in range(n_random): # decided by the user (how many times will the random iterations be repeated?) usually this is = 1000
        if degree_aware:
            if connected:
                raise ValueError("Not implemented!")
            # the lines below pick random nodes matching the degree (same bin) of the real nodes
            nodes_random = set()
            node_to_equivalent_nodes = get_degree_equivalents(nodes_selected, bins, network) # lists nodes in the same bin as the node of interest
            # now choose a random node from the same bin as the real node
            for node, equivalent_nodes in node_to_equivalent_nodes.items():
                chosen = random.choice(equivalent_nodes)
                for k in range(20):  # Try to find a distinct node (at most 20 times) - to make sure it doesn't choose the same node
                    if chosen in nodes_random:
                        chosen = random.choice(equivalent_nodes)
                nodes_random.add(chosen)
            nodes_random = list(nodes_random)
        else:
            if connected:
                nodes_random = [random.choice(nodes)]
                k = 1
                while True:
                    if k == len(nodes_selected):
                        break
                    node_random = random.choice(nodes_random)
                    node_selected = random.choice(network.neighbors(node_random))
                    if node_selected in nodes_random:
                        continue
                    nodes_random.append(node_selected)
                    k += 1
            else:
                nodes_random = random.sample(nodes, len(nodes_selected))
        values.append(nodes_random)
    return values

def get_random_nodes(nodes, network, bins=None, n_random=1000, min_bin_size=100, degree_aware=True, seed=None):
    '''
    This function creates a n_random number of lists of random nodes with the same degree binning as the real nodes (when degree_aware=True).
    usually n_random = 1000 because we often do 1000 iterations.
    '''
    if bins is None:
        # Get degree bins of the network (if they aren't already supplied
        bins = get_degree_binning(network, min_bin_size)
    # pick the random nodes
    nodes_random = pick_random_nodes_matching_selected(network, bins, nodes, n_random, degree_aware,
                                                                         seed=seed)
    return nodes_random

def calculate_proximity(network, drug, nodes_from, nodes_to, nodes_from_random=None, nodes_to_random=None, bins=None,
                        n_random=1000, min_bin_size=100, seed=452456):
    """
    Calculate proximity from nodes_from to nodes_to
    If degree binning or random nodes are not given, they are generated
    """

    nodes_network = set(network.nodes())
    nodes_from = set(nodes_from) & nodes_network # select only nodes_from (drug targets) that are located in the network
    nodes_to = set(nodes_to) & nodes_network # select only nodes_to (disease targets) that are located in the network
    if len(nodes_from) == 0 or len(nodes_to) == 0:
        return None  # At least one of the node group not in network
    d = calculate_closest_distance(network, nodes_from, nodes_to) # this is the real distance
    
    # now do 1000 iterations using random nodes
    if bins is None and (nodes_from_random is None or nodes_to_random is None):
        bins = get_degree_binning(network, min_bin_size)
    if nodes_from_random is None:
        nodes_from_random = get_random_nodes(nodes_from, network, bins=bins, n_random=n_random,
                                             min_bin_size=min_bin_size, seed=seed)
    if nodes_to_random is None:
        nodes_to_random = get_random_nodes(nodes_to, network, bins=bins, n_random=n_random, min_bin_size=min_bin_size,
                                           seed=seed)
    random_values_list = zip(nodes_from_random, nodes_to_random)
    values = numpy.empty(len(nodes_from_random))  # n_random
    # now calculates the closest distance using random nodes. Repeat x1000
    for i, values_random in enumerate(random_values_list):
        #print('iteration ', i)
        nodes_from, nodes_to = values_random
        values[i] = calculate_closest_distance(network, nodes_from, nodes_to)
    m, s = numpy.mean(values), numpy.std(values) # do mean and stdev of random iterations
    if s == 0:
        z = 0.0
    else:
        z = (d - m) / s
    dict = {'drug': drug, 'distance': d, 'z_score': z}
    return dict

# %% [markdown]
# ## Call function

# %%
import networkx as nx
import pandas as pd
import sys, time
import numpy
import random

# %%
# Create PPI network
ppi_df = pd.read_csv("../data/networks/combined_PPI.csv", sep=",")
ppi_graph = nx.from_pandas_edgelist(ppi_df, "GeneA", "GeneB")

# Get degree bins
bins = get_degree_binning(ppi_graph, bin_size=100)

# Print basic information about the graph
print(f"Number of nodes in PPI graph: {ppi_graph.number_of_nodes()}")
print(f"Number of edges in PPI graph: {ppi_graph.number_of_edges()}")
# Out:
# Number of nodes in PPI graph: 18451
# Number of edges in PPI graph: 345547

# %%
# Prepare DPI data
dpi_df = pd.read_csv("../data/networks/combined_DPI.csv", sep=",")

# Drop NA
dpi_df.dropna(inplace=True)

# Filter DPI to keep only drug targets that are in the PPI graph
dpi_df = dpi_df[dpi_df["Drug_Target"].isin(ppi_graph.nodes)]
drug_list = dpi_df["Drug_Name"].unique()

# Print basic information about the DPI
print(f"Number of drug targets retained in DPI: {len(drug_list)}")

# Create a mapping of drug names to their targets
drug_to_targets = dpi_df.groupby("Drug_Name")["Drug_Target"].apply(set).to_dict()
# Out:
# Number of drug targets retained in DPI: 2244

# %% [markdown]
# ### Define function for proximity analysis

# %%
def run_proximity_analysis(step_name, deg_file_path, output_csv_path, ppi_graph, drug_to_targets,
                           bins, n_random=1000, min_bin_size=100, seed=452456):
    """
    Calculate proximity for step_name using drugs and targets in drug_to_targets and disease genes in deg_file_path
    Saves the result as a CSV file at output_csv_path
    """
    print(f"\n===== Processing {step_name} =====")
    
    # ========== LOAD DISEASE GENES ==========
    disease_genes = pd.read_csv(deg_file_path, header=None)
    print(len(disease_genes), f"disease genes in {step_name}")
    disease_genes = disease_genes.iloc[:,0].dropna().unique().tolist()
    # Keep only disease genes that are in the PPI graph
    disease_genes = [gene for gene in disease_genes if gene in ppi_graph.nodes]
    print(len(disease_genes), f"disease genes in {step_name} after filtering for PPI graph")
    
    # ========== GENERATE RANDOM SETS OF DISEASE GENES ==========
    # For each disease gene, pick a random node from the same degree bin, and repeat this 1000 times, generating 1000 sets of random disease genes
    random_disease_genes = get_random_nodes(
        disease_genes,
        ppi_graph,
        bins=bins,
        n_random=n_random,
        min_bin_size=min_bin_size,
        seed=seed,
        degree_aware=True)
    print("Generated", len(random_disease_genes), "sets of random disease genes")

    # ========== RUN PROXIMITY ANALYSIS ==========
    results = []
    # Iterate over each drug and calculate proximity to disease genes
    for i, (drug, targets) in enumerate(drug_to_targets.items()):
        start = time.time()
        print(f"Processing drug: {drug}")

        # Calculate proximity to disease genes
        result = calculate_proximity(
            ppi_graph,
            drug,
            targets,
            disease_genes,
            nodes_from_random=random_disease_genes,
            bins=bins,
            n_random=n_random,
            min_bin_size=min_bin_size,
            seed=seed
        )

        if result is not None:
            results.append(result)
        else:
            print(f"No proximity data for drug: {drug}")

        if i % 50 == 0:
            print(f"{i}/{len(drug_to_targets)} drugs processed")

        end = time.time()
        print(f"Runtime: {(end - start):.2f} sec.")

    # Save and display
    results_df = pd.DataFrame(results)
    results_df.to_csv(output_csv_path, index=False)
    print(f"Saved results to {output_csv_path}")
    print("Top 10 prioritised drugs for", step_name, results_df.sort_values("z_score").head(10))

# %% [markdown]
# ### Call function for each step

# %%
# Define DEG file paths and output paths
steps = {
    "step1": {
        "deg_file": "../results/humanPVATsn/network_analysis/step1_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_step1_key_only.csv"
    },
    "step2": {
        "deg_file": ".../results/humanPVATsn/network_analysis/step2_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_step2_key_only.csv"
    },
    "step3": {
        "deg_file": "../results/humanPVATsn/network_analysis/step3_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_step3_key_only.csv"
    },
    "full": {
        "deg_file": "../results/humanPVATsn/network_analysis/full_key_genes_only.csv",
        "output_csv": "../results/humanPVATsn/network_analysis/proximity_full_key_only.csv"
    }
}

# Run proximity analysis for each step
for step, path in steps.items():
    run_proximity_analysis(step_name=step,
                           deg_file_path=path["deg_file"],
                           output_csv_path=path["output_csv"],
                           ppi_graph=ppi_graph,
                           drug_to_targets=drug_to_targets,
                           bins=bins,
                           n_random=100,
                           min_bin_size=100,
                           seed=452456)
# Out:
# ===== Processing step1 =====
# 22 disease genes in step1
# 22 disease genes in step1 after filtering for PPI graph
# Generated 100 sets of random disease genes
# Processing drug: (s)-camphor
# 0/2244 drugs processed
# Runtime: 5.53 sec.
# Processing drug: abacavir
# Runtime: 4.89 sec.
# Processing drug: abaloparatide
# Runtime: 4.89 sec.
# Processing drug: abametapir
# Runtime: 4.76 sec.
# Processing drug: abarelix
# Runtime: 4.68 sec.
# Processing drug: abatacept
# Runtime: 4.80 sec.
# Processing drug: abemaciclib
# Runtime: 4.78 sec.
# Processing drug: abiraterone
# Runtime: 5.06 sec.
# Processing drug: abiraterone acetate
# Runtime: 4.78 sec.
# Processing drug: abrocitinib
# Runtime: 4.84 sec.
# Processing drug: acalabrutinib
# Runtime: 4.69 sec.
# Processing drug: acamprosate
# Runtime: 4.87 sec.
# Processing drug: acarbose
# Runtime: 4.73 sec.
# Processing drug: acebutolol
# Runtime: 4.70 sec.
# Processing drug: aceclofenac
# Runtime: 4.73 sec.
# Processing drug: acefylline
# Runtime: 4.54 sec.
# Processing drug: acemetacin
# Runtime: 4.70 sec.
# Processing drug: acenocoumarol
# Runtime: 4.74 sec.
# Processing drug: acetaminophen
# Runtime: 4.74 sec.
# Processing drug: acetarsone
# Runtime: 4.67 sec.
# Processing drug: acetazolamide
# Runtime: 4.82 sec.
# Processing drug: acetohydroxamic acid
# Runtime: 5.62 sec.
# Processing drug: acetophenazine
# Runtime: 8.28 sec.
# Processing drug: acetylcholine
# Runtime: 5.09 sec.
# Processing drug: acetylcholine chloride
# Runtime: 5.15 sec.
# Processing drug: acetylcysteine
# Runtime: 4.89 sec.
# Processing drug: acetyldigitoxin
# Runtime: 4.74 sec.
# Processing drug: acetylsalicylic acid
# Runtime: 5.01 sec.
# Processing drug: acipimox
# Runtime: 6.02 sec.
# Processing drug: acitretin
# Runtime: 4.88 sec.
# Processing drug: aclidinium
# Runtime: 4.99 sec.
# Processing drug: aclidinium bromide
# Runtime: 4.84 sec.
# Processing drug: acyclovir
# Runtime: 4.80 sec.
# Processing drug: adagrasib
# Runtime: 4.78 sec.
# Processing drug: adalimumab
# Runtime: 5.08 sec.
# Processing drug: adapalene
# Runtime: 5.03 sec.
# Processing drug: adefovir dipivoxil
# Runtime: 5.57 sec.
# Processing drug: ademetionine
# Runtime: 4.94 sec.
# Processing drug: adenosine
# Runtime: 4.91 sec.
# Processing drug: aducanumab
# Runtime: 5.66 sec.
# Processing drug: afamelanotide
# Runtime: 5.53 sec.
# Processing drug: afatinib
# Runtime: 8.11 sec.
# Processing drug: afatinib dimaleate
# Runtime: 6.08 sec.
# Processing drug: aflibercept
# Runtime: 5.14 sec.
# Processing drug: agalsidase alfa
# Runtime: 5.36 sec.
# Processing drug: agkistrodon piscivorus antivenin
# Runtime: 5.32 sec.
# Processing drug: agomelatine
# Runtime: 5.00 sec.
# Processing drug: albuterol
# Runtime: 4.89 sec.
# Processing drug: albutrepenonacog alfa
# Runtime: 4.96 sec.
# Processing drug: alcaftadine
# Runtime: 7.15 sec.
# Processing drug: alclometasone
# 50/2244 drugs processed
# Runtime: 5.34 sec.
# Processing drug: aldesleukin
# Runtime: 5.35 sec.
# Processing drug: alectinib
# Runtime: 7.57 sec.
# Processing drug: alemtuzumab
# Runtime: 8.10 sec.
# Processing drug: alendronate sodium
# Runtime: 6.78 sec.
# Processing drug: alendronic acid
# Runtime: 5.02 sec.
# Processing drug: alfacalcidol
# Runtime: 5.06 sec.
# Processing drug: alfentanil
# Runtime: 7.05 sec.
# Processing drug: alfentanil hydrochloride
# Runtime: 5.32 sec.
# Processing drug: alfuzosin
# Runtime: 5.10 sec.
# Processing drug: alglucosidase alfa
# Runtime: 4.80 sec.
# Processing drug: alimemazine
# Runtime: 5.22 sec.
# Processing drug: alirocumab
# Runtime: 4.98 sec.
# Processing drug: aliskiren
# Runtime: 5.04 sec.
# Processing drug: aliskiren fumarate
# Runtime: 4.74 sec.
# Processing drug: alitretinoin
# Runtime: 5.38 sec.
# Processing drug: allopurinol
# Runtime: 6.53 sec.
# Processing drug: almitrine
# Runtime: 5.61 sec.
# Processing drug: almotriptan
# Runtime: 5.00 sec.
# Processing drug: alogliptin
# Runtime: 4.79 sec.
# Processing drug: alosetron
# Runtime: 4.88 sec.
# Processing drug: alpelisib
# Runtime: 4.86 sec.
# Processing drug: alpha-1-proteinase inhibitor
# Runtime: 4.77 sec.
# Processing drug: alprazolam
# Runtime: 4.85 sec.
# Processing drug: alprostadil
# Runtime: 5.46 sec.
# Processing drug: alteplase
# Runtime: 5.39 sec.
# Processing drug: altretamine
# Runtime: 7.02 sec.
# Processing drug: alvimopan
# Runtime: 5.20 sec.
# Processing drug: amantadine
# Runtime: 4.73 sec.
# Processing drug: ambrisentan
# Runtime: 4.77 sec.
# Processing drug: amcinonide
# Runtime: 4.91 sec.
# Processing drug: amifampridine
# Runtime: 4.86 sec.
# Processing drug: amifostine
# Runtime: 4.77 sec.
# Processing drug: amiloride
# Runtime: 4.69 sec.
# Processing drug: amiloride hydrochloride
# Runtime: 4.69 sec.
# Processing drug: aminobenzoic acid
# Runtime: 6.89 sec.
# Processing drug: aminocaproic acid
# Runtime: 5.58 sec.
# Processing drug: aminoglutethimide
# Runtime: 5.11 sec.
# Processing drug: aminolevulinic acid
# Runtime: 5.23 sec.
# Processing drug: aminophylline
# Runtime: 4.94 sec.
# Processing drug: aminosalicylic acid
# Runtime: 4.73 sec.
# Processing drug: amiodarone
# Runtime: 4.94 sec.
# Processing drug: amisulpride
# Runtime: 4.90 sec.
# Processing drug: amitriptyline
# Runtime: 4.84 sec.
# Processing drug: amitriptyline hydrochloride
# Runtime: 599.59 sec.
# Processing drug: amivantamab
# Runtime: 4.90 sec.
# Processing drug: amlexanox
# Runtime: 4.31 sec.
# Processing drug: amlodipine
# Runtime: 4.32 sec.
# Processing drug: amlodipine besylate
# Runtime: 4.32 sec.
# Processing drug: amodiaquine
# Runtime: 4.46 sec.
# Processing drug: amoxapine
# 100/2244 drugs processed
# Runtime: 4.36 sec.
# Processing drug: amoxicillin
# Runtime: 4.30 sec.
# Processing drug: amphetamine
# Runtime: 4.29 sec.
# Processing drug: amphotericin b
# Runtime: 4.28 sec.
# Processing drug: ampicillin
# Runtime: 4.32 sec.
# Processing drug: amprenavir
# Runtime: 4.34 sec.
# Processing drug: amsacrine
# Runtime: 4.31 sec.
# Processing drug: amyl nitrite
# Runtime: 4.29 sec.
# Processing drug: anagrelide
# Runtime: 4.29 sec.
# Processing drug: anakinra
# Runtime: 4.30 sec.
# Processing drug: anastrozole
# Runtime: 4.30 sec.
# Processing drug: andexanet alfa
# Runtime: 4.33 sec.
# Processing drug: angiotensin ii
# Runtime: 4.38 sec.
# Processing drug: anidulafungin
# Runtime: 6.76 sec.
# Processing drug: anifrolumab
# Runtime: 4.55 sec.
# Processing drug: anisindione
# Runtime: 14.37 sec.
# Processing drug: anisotropine methylbromide
# Runtime: 21.78 sec.
# Processing drug: antazoline
# Runtime: 22.23 sec.
# Processing drug: antazoline hydrochloride
# Runtime: 16.46 sec.
# Processing drug: anthralin
# Runtime: 4.37 sec.
# Processing drug: anti-inhibitor coagulant complex
# Runtime: 4.35 sec.
# Processing drug: antihemophilic factor (recombinant), pegylated
# Runtime: 4.41 sec.
# Processing drug: antihemophilic factor human
# Runtime: 4.33 sec.
# Processing drug: antihemophilic factor, human recombinant
# Runtime: 4.36 sec.
# Processing drug: antipyrine
# Runtime: 4.33 sec.
# Processing drug: antithrombin alfa
# Runtime: 4.30 sec.
# Processing drug: antithymocyte immunoglobulin (rabbit)
# Runtime: 4.54 sec.
# Processing drug: apadamtase alfa
# Runtime: 4.53 sec.
# Processing drug: apalutamide
# Runtime: 4.45 sec.
# Processing drug: apixaban
# Runtime: 4.29 sec.
# Processing drug: apomorphine
# Runtime: 4.45 sec.
# Processing drug: apomorphine hydrochloride
# Runtime: 4.43 sec.
# Processing drug: apraclonidine
# Runtime: 4.33 sec.
# Processing drug: apremilast
# Runtime: 16.10 sec.
# Processing drug: aprepitant
# Runtime: 15.11 sec.
# Processing drug: aprocitentan
# Runtime: 22.03 sec.
# Processing drug: arbutamine
# Runtime: 20.88 sec.
# Processing drug: arbutin
# Runtime: 21.72 sec.
# Processing drug: arformoterol
# Runtime: 16.60 sec.
# Processing drug: argatroban
# Runtime: 4.31 sec.
# Processing drug: aripiprazole
# Runtime: 4.36 sec.
# Processing drug: aripiprazole lauroxil
# Runtime: 4.30 sec.
# Processing drug: armodafinil
# Runtime: 4.37 sec.
# Processing drug: arsenic trioxide
# Runtime: 4.40 sec.
# Processing drug: articaine
# Runtime: 4.77 sec.
# Processing drug: asciminib
# Runtime: 4.48 sec.
# Processing drug: asenapine
# Runtime: 4.32 sec.
# Processing drug: asenapine maleate
# Runtime: 4.39 sec.
# Processing drug: aspirin
# Runtime: 7.95 sec.
# Processing drug: astemizole
# Runtime: 7.84 sec.
# Processing drug: ataluren
# 150/2244 drugs processed
# Runtime: 8.26 sec.
# Processing drug: atazanavir
# Runtime: 5.36 sec.
# Processing drug: atenolol
# Runtime: 4.83 sec.
# Processing drug: atezolizumab
# Runtime: 4.95 sec.
# Processing drug: atogepant
# Runtime: 4.86 sec.
# Processing drug: atomoxetine
# Runtime: 5.08 sec.
# Processing drug: atomoxetine hydrochloride
# Runtime: 201.92 sec.
# Processing drug: atorvastatin
# Runtime: 4.50 sec.
# Processing drug: atorvastatin calcium
# Runtime: 4.32 sec.
# Processing drug: atosiban
# Runtime: 4.29 sec.
# Processing drug: atovaquone
# Runtime: 4.30 sec.
# Processing drug: atracurium besylate
# Runtime: 4.28 sec.
# Processing drug: atrasentan
# Runtime: 4.33 sec.
# Processing drug: atropine
# Runtime: 4.31 sec.
# Processing drug: auranofin
# Runtime: 4.31 sec.
# Processing drug: avacopan
# Runtime: 4.31 sec.
# Processing drug: avalglucosidase alfa
# Runtime: 4.32 sec.
# Processing drug: avanafil
# Runtime: 4.28 sec.
# Processing drug: avapritinib
# Runtime: 4.33 sec.
# Processing drug: avelumab
# Runtime: 4.31 sec.
# Processing drug: axatilimab
# Runtime: 4.30 sec.
# Processing drug: axicabtagene ciloleucel
# Runtime: 4.29 sec.
# Processing drug: axitinib
# Runtime: 4.41 sec.
# Processing drug: azacitidine
# Runtime: 4.30 sec.
# Processing drug: azathioprine
# Runtime: 4.31 sec.
# Processing drug: azelaic acid
# Runtime: 4.30 sec.
# Processing drug: azelastine
# Runtime: 4.28 sec.
# Processing drug: azelastine hydrochloride
# Runtime: 4.30 sec.
# Processing drug: azilsartan medoxomil
# Runtime: 4.29 sec.
# Processing drug: bacitracin
# Runtime: 4.29 sec.
# Processing drug: baclofen
# Runtime: 4.33 sec.
# Processing drug: balsalazide
# Runtime: 4.29 sec.
# Processing drug: baricitinib
# Runtime: 4.43 sec.
# Processing drug: basiliximab
# Runtime: 4.30 sec.
# Processing drug: bazedoxifene
# Runtime: 4.29 sec.
# Processing drug: becaplermin
# Runtime: 4.39 sec.
# Processing drug: beclomethasone dipropionate
# Runtime: 4.29 sec.
# Processing drug: bedaquiline
# Runtime: 4.29 sec.
# Processing drug: belatacept
# Runtime: 4.29 sec.
# Processing drug: belimumab
# Runtime: 4.29 sec.
# Processing drug: belinostat
# Runtime: 4.30 sec.
# Processing drug: belumosudil
# Runtime: 4.45 sec.
# Processing drug: belzutifan
# Runtime: 6.13 sec.
# Processing drug: bempedoic acid
# Runtime: 4.78 sec.
# Processing drug: benazepril
# Runtime: 12.82 sec.
# Processing drug: bendamustine
# Runtime: 21.35 sec.
# Processing drug: bendroflumethiazide
# Runtime: 20.59 sec.
# Processing drug: benoxinate
# Runtime: 15.68 sec.
# Processing drug: benperidol
# Runtime: 4.28 sec.
# Processing drug: benralizumab
# Runtime: 4.27 sec.
# Processing drug: benserazide
# 200/2244 drugs processed
# Runtime: 4.39 sec.
# Processing drug: benzatropine
# Runtime: 4.29 sec.
# Processing drug: benzbromarone
# Runtime: 4.32 sec.
# Processing drug: benzgalantamine
# Runtime: 4.28 sec.
# Processing drug: benzhydrocodone
# Runtime: 4.27 sec.
# Processing drug: benznidazole
# Runtime: 4.30 sec.
# Processing drug: benzocaine
# Runtime: 4.29 sec.
# Processing drug: benzoic acid
# Runtime: 4.28 sec.
# Processing drug: benzoin
# Runtime: 4.29 sec.
# Processing drug: benzthiazide
# Runtime: 4.34 sec.
# Processing drug: benztropine
# Runtime: 4.32 sec.
# Processing drug: benzydamine
# Runtime: 4.36 sec.
# Processing drug: benzyl benzoate
# Runtime: 4.30 sec.
# Processing drug: benzylpenicillin
# Runtime: 4.30 sec.
# Processing drug: benzylpenicilloyl polylysine
# Runtime: 4.31 sec.
# Processing drug: bepotastine
# Runtime: 4.31 sec.
# Processing drug: bepridil
# Runtime: 4.30 sec.
# Processing drug: berotralstat
# Runtime: 4.29 sec.
# Processing drug: betahistine
# Runtime: 4.29 sec.
# Processing drug: betaine
# Runtime: 4.33 sec.
# Processing drug: betamethasone
# Runtime: 4.29 sec.
# Processing drug: betamethasone phosphate
# Runtime: 4.29 sec.
# Processing drug: betamethasone phosphoric acid
# Runtime: 4.29 sec.
# Processing drug: betaxolol
# Runtime: 4.36 sec.
# Processing drug: betaxolol hydrochloride
# Runtime: 4.30 sec.
# Processing drug: betazole
# Runtime: 4.31 sec.
# Processing drug: bethanechol
# Runtime: 5.11 sec.
# Processing drug: bethanidine
# Runtime: 20.77 sec.
# Processing drug: betrixaban
# Runtime: 20.76 sec.
# Processing drug: bevacizumab
# Runtime: 15.77 sec.
# Processing drug: bexagliflozin
# Runtime: 4.30 sec.
# Processing drug: bexarotene
# Runtime: 4.31 sec.
# Processing drug: bezafibrate
# Runtime: 4.31 sec.
# Processing drug: bicalutamide
# Runtime: 4.29 sec.
# Processing drug: bifonazole
# Runtime: 4.30 sec.
# Processing drug: bilastine
# Runtime: 4.28 sec.
# Processing drug: bimatoprost
# Runtime: 4.29 sec.
# Processing drug: bimekizumab
# Runtime: 4.28 sec.
# Processing drug: binimetinib
# Runtime: 4.28 sec.
# Processing drug: biperiden
# Runtime: 4.28 sec.
# Processing drug: bisacodyl
# Runtime: 4.29 sec.
# Processing drug: bisoprolol
# Runtime: 4.53 sec.
# Processing drug: bivalirudin
# Runtime: 4.29 sec.
# Processing drug: bleomycin
# Runtime: 4.73 sec.
# Processing drug: blinatumomab
# Runtime: 4.29 sec.
# Processing drug: boceprevir
# Runtime: 4.41 sec.
# Processing drug: bortezomib
# Runtime: 4.59 sec.
# Processing drug: bosentan
# Runtime: 4.56 sec.
# Processing drug: bosutinib
# Runtime: 14.45 sec.
# Processing drug: botulinum toxin type a
# Runtime: 20.58 sec.
# Processing drug: botulinum toxin type b
# 250/2244 drugs processed
# Runtime: 20.72 sec.
# Processing drug: bremelanotide
# Runtime: 10.88 sec.
# Processing drug: brentuximab vedotin
# Runtime: 4.35 sec.
# Processing drug: bretylium
# Runtime: 4.54 sec.
# Processing drug: brexanolone
# Runtime: 4.56 sec.
# Processing drug: brexpiprazole
# Runtime: 4.57 sec.
# Processing drug: brexucabtagene autoleucel
# Runtime: 4.51 sec.
# Processing drug: brigatinib
# Runtime: 4.54 sec.
# Processing drug: brimonidine
# Runtime: 4.58 sec.
# Processing drug: brinzolamide
# Runtime: 4.57 sec.
# Processing drug: brivaracetam
# Runtime: 4.56 sec.
# Processing drug: brivudine
# Runtime: 4.71 sec.
# Processing drug: brolucizumab
# Runtime: 4.64 sec.
# Processing drug: bromfenac
# Runtime: 4.72 sec.
# Processing drug: bromhexine
# Runtime: 4.78 sec.
# Processing drug: bromocriptine
# Runtime: 4.82 sec.
# Processing drug: bromodiphenhydramine
# Runtime: 4.79 sec.
# Processing drug: brompheniramine
# Runtime: 4.82 sec.
# Processing drug: buclizine
# Runtime: 4.91 sec.
# Processing drug: budesonide
# Runtime: 5.04 sec.
# Processing drug: bufexamac
# Runtime: 5.10 sec.
# Processing drug: bulevirtide
# Runtime: 5.25 sec.
# Processing drug: bumetanide
# Runtime: 5.20 sec.
# Processing drug: bupivacaine
# Runtime: 5.32 sec.
# Processing drug: bupivacaine hydrochloride
# Runtime: 5.19 sec.
# Processing drug: buprenorphine
# Runtime: 5.25 sec.
# Processing drug: buprenorphine hydrochloride
# Runtime: 5.27 sec.
# Processing drug: bupropion
# Runtime: 5.33 sec.
# Processing drug: bupropion hydrochloride
# Runtime: 5.35 sec.
# Processing drug: buserelin
# Runtime: 5.51 sec.
# Processing drug: buspirone
# Runtime: 5.50 sec.
# Processing drug: busulfan
# Runtime: 5.60 sec.
# Processing drug: butenafine
# Runtime: 5.73 sec.
# Processing drug: butorphanol
# Runtime: 5.66 sec.
# Processing drug: butylscopolamine
# Runtime: 5.67 sec.
# Processing drug: cabazitaxel
# Runtime: 5.60 sec.
# Processing drug: cabergoline
# Runtime: 6.20 sec.
# Processing drug: cabozantinib
# Runtime: 6.11 sec.
# Processing drug: cabozantinib s-malate
# Runtime: 5.46 sec.
# Processing drug: caffeine
# Runtime: 5.53 sec.
# Processing drug: calcifediol anhydrous
# Runtime: 5.45 sec.
# Processing drug: calcipotriene
# Runtime: 5.76 sec.
# Processing drug: calcipotriol
# Runtime: 17.24 sec.
# Processing drug: calcitriol
# Runtime: 5.27 sec.
# Processing drug: canagliflozin
# Runtime: 4.78 sec.
# Processing drug: canagliflozin anhydrous
# Runtime: 4.59 sec.
# Processing drug: canakinumab
# Runtime: 6.17 sec.
# Processing drug: candesartan cilexetil
# Runtime: 4.55 sec.
# Processing drug: cangrelor
# Runtime: 4.58 sec.
# Processing drug: cangrelor tetrasodium
# Runtime: 4.58 sec.
# Processing drug: cannabidiol
# 300/2244 drugs processed
# Runtime: 4.77 sec.
# Processing drug: cantharidin
# Runtime: 4.95 sec.
# Processing drug: capecitabine
# Runtime: 5.03 sec.
# Processing drug: capivasertib
# Runtime: 5.40 sec.
# Processing drug: caplacizumab
# Runtime: 5.12 sec.
# Processing drug: capmatinib
# Runtime: 5.13 sec.
# Processing drug: capsaicin
# Runtime: 5.44 sec.
# Processing drug: capsicum oleoresin
# Runtime: 5.31 sec.
# Processing drug: captopril
# Runtime: 10.87 sec.
# Processing drug: carbachol
# Runtime: 20.74 sec.
# Processing drug: carbamazepine
# Runtime: 21.55 sec.
# Processing drug: carbamoylcholine
# Runtime: 12.52 sec.
# Processing drug: carbenoxolone
# Runtime: 4.99 sec.
# Processing drug: carbetocin
# Runtime: 5.25 sec.
# Processing drug: carbidopa
# Runtime: 5.37 sec.
# Processing drug: carbimazole
# Runtime: 5.59 sec.
# Processing drug: carbinoxamine
# Runtime: 5.31 sec.
# Processing drug: carbon monoxide
# Runtime: 5.41 sec.
# Processing drug: carboprost tromethamine
# Runtime: 5.23 sec.
# Processing drug: carboxymethylcellulose
# Runtime: 5.22 sec.
# Processing drug: carfilzomib
# Runtime: 5.42 sec.
# Processing drug: carglumic acid
# Runtime: 5.24 sec.
# Processing drug: cariprazine
# Runtime: 5.21 sec.
# Processing drug: cariprazine hydrochloride
# Runtime: 5.25 sec.
# Processing drug: carisoprodol
# Runtime: 5.26 sec.
# Processing drug: carmustine
# Runtime: 5.51 sec.
# Processing drug: carprofen
# Runtime: 6.86 sec.
# Processing drug: carteolol
# Runtime: 5.75 sec.
# Processing drug: carvedilol
# Runtime: 6.29 sec.
# Processing drug: casopitant
# Runtime: 5.55 sec.
# Processing drug: caspofungin
# Runtime: 5.49 sec.
# Processing drug: catridecacog
# Runtime: 5.73 sec.
# Processing drug: cedazuridine
# Runtime: 5.85 sec.
# Processing drug: cediranib
# Runtime: 5.95 sec.
# Processing drug: cefaclor anhydrous
# Runtime: 5.88 sec.
# Processing drug: cefadroxil
# Runtime: 5.75 sec.
# Processing drug: cefamandole
# Runtime: 5.83 sec.
# Processing drug: cefazolin
# Runtime: 5.82 sec.
# Processing drug: cefazolin sodium
# Runtime: 6.36 sec.
# Processing drug: cefdinir
# Runtime: 6.29 sec.
# Processing drug: cefepime
# Runtime: 6.28 sec.
# Processing drug: cefixime
# Runtime: 6.61 sec.
# Processing drug: cefmetazole
# Runtime: 9.30 sec.
# Processing drug: cefodizime
# Runtime: 6.23 sec.
# Processing drug: cefoperazone
# Runtime: 6.09 sec.
# Processing drug: cefotaxime
# Runtime: 6.08 sec.
# Processing drug: cefotaxime sodium
# Runtime: 6.10 sec.
# Processing drug: cefotetan
# Runtime: 6.58 sec.
# Processing drug: cefoxitin
# Runtime: 6.41 sec.
# Processing drug: cefpodoxime proxetil
# Runtime: 6.70 sec.
# Processing drug: cefsulodin
# 350/2244 drugs processed
# Runtime: 6.18 sec.
# Processing drug: cefsulodin sodium
# Runtime: 5.97 sec.
# Processing drug: ceftibuten
# Runtime: 5.98 sec.
# Processing drug: ceftriaxone
# Runtime: 5.95 sec.
# Processing drug: cefuroxime
# Runtime: 5.88 sec.
# Processing drug: cefuroxime axetil
# Runtime: 6.29 sec.
# Processing drug: cefuroxime sodium
# Runtime: 6.32 sec.
# Processing drug: celecoxib
# Runtime: 6.68 sec.
# Processing drug: celiprolol
# Runtime: 6.20 sec.
# Processing drug: cemiplimab
# Runtime: 6.17 sec.
# Processing drug: cenegermin
# Runtime: 6.66 sec.
# Processing drug: cephalexin anhydrous
# Runtime: 7.95 sec.
# Processing drug: cephalothin
# Runtime: 5.89 sec.
# Processing drug: cephalothin sodium
# Runtime: 5.86 sec.
# Processing drug: cephapirin sodium
# Runtime: 5.91 sec.
# Processing drug: cephradine
# Runtime: 6.08 sec.
# Processing drug: ceritinib
# Runtime: 6.22 sec.
# Processing drug: cerivastatin
# Runtime: 6.74 sec.
# Processing drug: certolizumab pegol
# Runtime: 6.49 sec.
# Processing drug: ceruletide
# Runtime: 6.50 sec.
# Processing drug: cetirizine
# Runtime: 6.13 sec.
# Processing drug: cetrimide
# Runtime: 8.59 sec.
# Processing drug: cetrorelix
# Runtime: 6.69 sec.
# Processing drug: cetrorelix acetate
# Runtime: 6.06 sec.
# Processing drug: cetuximab
# Runtime: 6.06 sec.
# Processing drug: cetylpyridinium chloride
# Runtime: 6.36 sec.
# Processing drug: cevimeline
# Runtime: 6.17 sec.
# Processing drug: chenodeoxycholic acid
# Runtime: 6.09 sec.
# Processing drug: chenodiol
# Runtime: 6.41 sec.
# Processing drug: chlorambucil
# Runtime: 7.39 sec.
# Processing drug: chloramphenicol
# Runtime: 7.97 sec.
# Processing drug: chlorcyclizine
# Runtime: 5.87 sec.
# Processing drug: chlordiazepoxide
# Runtime: 5.87 sec.
# Processing drug: chlorhexidine
# Runtime: 5.89 sec.
# Processing drug: chlorobutanol
# Runtime: 6.05 sec.
# Processing drug: chloroquine
# Runtime: 7.24 sec.
# Processing drug: chloroquine phosphate
# Runtime: 6.36 sec.
# Processing drug: chlorothiazide
# Runtime: 6.29 sec.
# Processing drug: chloroxine
# Runtime: 6.16 sec.
# Processing drug: chloroxylenol
# Runtime: 6.18 sec.
# Processing drug: chlorpheniramine
# Runtime: 6.18 sec.
# Processing drug: chlorpromazine
# Runtime: 6.45 sec.
# Processing drug: chlorpromazine hydrochloride
# Runtime: 6.23 sec.
# Processing drug: chlorpropamide
# Runtime: 10.93 sec.
# Processing drug: chlorprothixene
# Runtime: 4.72 sec.
# Processing drug: chlortetracycline
# Runtime: 4.41 sec.
# Processing drug: chlorthalidone
# Runtime: 4.80 sec.
# Processing drug: chlorzoxazone
# Runtime: 5.15 sec.
# Processing drug: cholecalciferol
# Runtime: 4.89 sec.
# Processing drug: cholesterol
# Runtime: 6.09 sec.
# Processing drug: cholic acid
# 400/2244 drugs processed
# Runtime: 4.93 sec.
# Processing drug: choline magnesium trisalicylate
# Runtime: 5.04 sec.
# Processing drug: choriogonadotropin alfa
# Runtime: 245.21 sec.
# Processing drug: chorionic gonadotropin (human)
# Runtime: 4.28 sec.
# Processing drug: chromic chloride
# Runtime: 4.43 sec.
# Processing drug: ciclesonide
# Runtime: 4.35 sec.
# Processing drug: ciclopirox
# Runtime: 4.32 sec.
# Processing drug: cidofovir
# Runtime: 4.30 sec.
# Processing drug: cilastatin
# Runtime: 4.33 sec.
# Processing drug: cilazapril
# Runtime: 4.34 sec.
# Processing drug: cilostazol
# Runtime: 4.29 sec.
# Processing drug: ciltacabtagene autoleucel
# Runtime: 4.29 sec.
# Processing drug: cimetidine
# Runtime: 6.39 sec.
# Processing drug: cinacalcet
# Runtime: 4.46 sec.
# Processing drug: cinacalcet hydrochloride
# Runtime: 4.34 sec.
# Processing drug: cinchocaine
# Runtime: 4.28 sec.
# Processing drug: cinnarizine
# Runtime: 4.34 sec.
# Processing drug: cipaglucosidase alfa
# Runtime: 4.27 sec.
# Processing drug: ciprofibrate
# Runtime: 4.31 sec.
# Processing drug: ciprofloxacin
# Runtime: 4.32 sec.
# Processing drug: ciprofloxacin hydrochloride
# Runtime: 4.32 sec.
# Processing drug: cisapride
# Runtime: 4.34 sec.
# Processing drug: cisplatin
# Runtime: 4.80 sec.
# Processing drug: citalopram
# Runtime: 732.52 sec.
# Processing drug: citalopram hydrobromide
# Runtime: 4.61 sec.
# Processing drug: cladribine
# Runtime: 4.69 sec.
# Processing drug: clarithromycin
# Runtime: 5.23 sec.
# Processing drug: clascoterone
# Runtime: 4.70 sec.
# Processing drug: clebopride
# Runtime: 4.51 sec.
# Processing drug: clemastine
# Runtime: 4.51 sec.
# Processing drug: clenbuterol
# Runtime: 4.50 sec.
# Processing drug: clevidipine
# Runtime: 4.40 sec.
# Processing drug: clidinium
# Runtime: 4.36 sec.
# Processing drug: clindamycin
# Runtime: 4.44 sec.
# Processing drug: clindamycin phosphate
# Runtime: 4.30 sec.
# Processing drug: clioquinol
# Runtime: 4.43 sec.
# Processing drug: clobetasol propionate
# Runtime: 4.29 sec.
# Processing drug: clobetasone
# Runtime: 4.28 sec.
# Processing drug: clocortolone
# Runtime: 751.21 sec.
# Processing drug: clodronic acid
# Runtime: 5.17 sec.
# Processing drug: clofarabine
# Runtime: 4.81 sec.
# Processing drug: clofazimine
# Runtime: 4.54 sec.
# Processing drug: clofibrate
# Runtime: 4.52 sec.
# Processing drug: clomifene
# Runtime: 4.53 sec.
# Processing drug: clomiphene
# Runtime: 4.74 sec.
# Processing drug: clomipramine
# Runtime: 4.57 sec.
# Processing drug: clonazepam
# Runtime: 4.58 sec.
# Processing drug: clonidine
# Runtime: 4.53 sec.
# Processing drug: clonidine hydrochloride
# Runtime: 4.71 sec.
# Processing drug: clopidogrel
# Runtime: 4.72 sec.
# Processing drug: clopidogrel bisulfate
# 450/2244 drugs processed
# Runtime: 5.71 sec.
# Processing drug: clothiapine
# Runtime: 5.38 sec.
# Processing drug: clotrimazole
# Runtime: 5.04 sec.
# Processing drug: cloxacillin
# Runtime: 4.83 sec.
# Processing drug: clozapine
# Runtime: 4.56 sec.
# Processing drug: coagulation factor ix (recombinant)
# Runtime: 4.36 sec.
# Processing drug: coagulation factor ix human
# Runtime: 4.34 sec.
# Processing drug: coagulation factor vii human
# Runtime: 4.29 sec.
# Processing drug: coagulation factor viia recombinant human
# Runtime: 4.29 sec.
# Processing drug: cobicistat
# Runtime: 4.33 sec.
# Processing drug: cobimetinib
# Runtime: 4.30 sec.
# Processing drug: cocaine
# Runtime: 4.35 sec.
# Processing drug: cocaine hydrochloride
# Runtime: 4.31 sec.
# Processing drug: codeine
# Runtime: 4.34 sec.
# Processing drug: colchicine
# Runtime: 4.35 sec.
# Processing drug: colistin
# Runtime: 4.31 sec.
# Processing drug: collagenase clostridium histolyticum
# Runtime: 4.29 sec.
# Processing drug: concizumab
# Runtime: 4.39 sec.
# Processing drug: conestat alfa
# Runtime: 4.29 sec.
# Processing drug: conivaptan
# Runtime: 4.31 sec.
# Processing drug: conjugated estrogens
# Runtime: 4.29 sec.
# Processing drug: copanlisib
# Runtime: 4.30 sec.
# Processing drug: corifollitropin alfa
# Runtime: 4.29 sec.
# Processing drug: corticorelin ovine triflutate
# Runtime: 4.32 sec.
# Processing drug: corticotropin
# Runtime: 4.32 sec.
# Processing drug: cortisone acetate
# Runtime: 4.33 sec.
# Processing drug: cosyntropin
# Runtime: 4.29 sec.
# Processing drug: coumarin
# Runtime: 4.81 sec.
# Processing drug: crisaborole
# Runtime: 4.38 sec.
# Processing drug: crizanlizumab
# Runtime: 4.28 sec.
# Processing drug: crizotinib
# Runtime: 4.47 sec.
# Processing drug: crofelemer
# Runtime: 4.28 sec.
# Processing drug: cromolyn
# Runtime: 4.27 sec.
# Processing drug: cromolyn sodium
# Runtime: 4.27 sec.
# Processing drug: crotalus adamanteus antivenin
# Runtime: 4.31 sec.
# Processing drug: crotamiton
# Runtime: 4.28 sec.
# Processing drug: crovalimab
# Runtime: 4.26 sec.
# Processing drug: cryptenamine
# Runtime: 4.29 sec.
# Processing drug: cyclacillin
# Runtime: 4.30 sec.
# Processing drug: cyclandelate
# Runtime: 4.28 sec.
# Processing drug: cyclizine
# Runtime: 4.29 sec.
# Processing drug: cyclobenzaprine
# Runtime: 4.30 sec.
# Processing drug: cyclofenil
# Runtime: 4.32 sec.
# Processing drug: cyclopentolate
# Runtime: 4.30 sec.
# Processing drug: cycloserine
# Runtime: 4.28 sec.
# Processing drug: cyclosporine
# Runtime: 4.30 sec.
# Processing drug: cyclothiazide
# Runtime: 4.29 sec.
# Processing drug: cycrimine
# Runtime: 4.27 sec.
# Processing drug: cyproheptadine
# Runtime: 4.33 sec.
# Processing drug: cyproterone acetate
# Runtime: 4.29 sec.
# Processing drug: cysteamine
# 500/2244 drugs processed
# Runtime: 4.27 sec.
# Processing drug: cytarabine
# Runtime: 4.32 sec.
# Processing drug: d-methionine
# Runtime: 4.30 sec.
# Processing drug: dabigatran etexilate
# Runtime: 4.41 sec.
# Processing drug: dabrafenib
# Runtime: 4.35 sec.
# Processing drug: dacarbazine
# Runtime: 4.68 sec.
# Processing drug: daclatasvir
# Runtime: 4.28 sec.
# Processing drug: dacomitinib
# Runtime: 4.28 sec.
# Processing drug: dacomitinib anhydrous
# Runtime: 4.29 sec.
# Processing drug: dactinomycin
# Runtime: 4.28 sec.
# Processing drug: dalfampridine
# Runtime: 4.31 sec.
# Processing drug: dalteparin
# Runtime: 4.28 sec.
# Processing drug: damoctocog alfa pegol
# Runtime: 4.28 sec.
# Processing drug: danazol
# Runtime: 4.31 sec.
# Processing drug: dantrolene
# Runtime: 4.29 sec.
# Processing drug: dapagliflozin
# Runtime: 4.29 sec.
# Processing drug: dapiprazole
# Runtime: 4.31 sec.
# Processing drug: daprodustat
# Runtime: 4.29 sec.
# Processing drug: dapsone
# Runtime: 4.28 sec.
# Processing drug: daptomycin
# Runtime: 4.39 sec.
# Processing drug: daratumumab
# Runtime: 4.31 sec.
# Processing drug: darbepoetin alfa
# Runtime: 4.28 sec.
# Processing drug: daridorexant
# Runtime: 4.29 sec.
# Processing drug: darifenacin
# Runtime: 4.30 sec.
# Processing drug: darolutamide
# Runtime: 4.28 sec.
# Processing drug: darunavir
# Runtime: 6.42 sec.
# Processing drug: dasabuvir
# Runtime: 4.53 sec.
# Processing drug: dasatinib
# Runtime: 4.38 sec.
# Processing drug: dasiglucagon
# Runtime: 4.41 sec.
# Processing drug: datopotamab deruxtecan
# Runtime: 4.49 sec.
# Processing drug: daunorubicin
# Runtime: 4.45 sec.
# Processing drug: daunorubicin hydrochloride
# Runtime: 4.36 sec.
# Processing drug: daxibotulinumtoxina
# Runtime: 4.39 sec.
# Processing drug: debrisoquin
# Runtime: 10.67 sec.
# Processing drug: debrisoquine
# Runtime: 8.10 sec.
# Processing drug: decamethonium
# Runtime: 5.88 sec.
# Processing drug: decamethonium bromide
# Runtime: 5.83 sec.
# Processing drug: decitabine
# Runtime: 6.88 sec.
# Processing drug: deferasirox
# Runtime: 6.01 sec.
# Processing drug: deferiprone
# Runtime: 5.69 sec.
# Processing drug: deferoxamine
# Runtime: 5.39 sec.
# Processing drug: defibrotide
# Runtime: 5.36 sec.
# Processing drug: deflazacort
# Runtime: 5.30 sec.
# Processing drug: degarelix
# Runtime: 5.30 sec.
# Processing drug: delavirdine
# Runtime: 5.29 sec.
# Processing drug: delgocitinib
# Runtime: 5.27 sec.
# Processing drug: demecarium
# Runtime: 5.31 sec.
# Processing drug: demeclocycline
# Runtime: 5.30 sec.
# Processing drug: demeclocycline hydrochloride
# Runtime: 5.30 sec.
# Processing drug: denileukin diftitox
# Runtime: 5.27 sec.
# Processing drug: denosumab
# 550/2244 drugs processed
# Runtime: 5.30 sec.
# Processing drug: deoxycholic acid
# Runtime: 5.53 sec.
# Processing drug: dequalinium
# Runtime: 5.45 sec.
# Processing drug: dequalinium chloride
# Runtime: 6.38 sec.
# Processing drug: desflurane
# Runtime: 5.75 sec.
# Processing drug: desipramine
# Runtime: 5.51 sec.
# Processing drug: desipramine hydrochloride
# Runtime: 5.41 sec.
# Processing drug: deslanoside
# Runtime: 5.31 sec.
# Processing drug: desloratadine
# Runtime: 5.44 sec.
# Processing drug: desmopressin
# Runtime: 5.46 sec.
# Processing drug: desogestrel
# Runtime: 5.39 sec.
# Processing drug: desonide
# Runtime: 5.13 sec.
# Processing drug: desoximetasone
# Runtime: 4.79 sec.
# Processing drug: desvenlafaxine
# Runtime: 4.73 sec.
# Processing drug: deucravacitinib
# Runtime: 4.63 sec.
# Processing drug: deutetrabenazine
# Runtime: 4.63 sec.
# Processing drug: dexamethasone
# Runtime: 4.74 sec.
# Processing drug: dexamethasone acetate
# Runtime: 5.11 sec.
# Processing drug: dexbrompheniramine
# Runtime: 4.53 sec.
# Processing drug: dexchlorpheniramine
# Runtime: 4.64 sec.
# Processing drug: dexchlorpheniramine maleate
# Runtime: 4.81 sec.
# Processing drug: dexfenfluramine
# Runtime: 4.61 sec.
# Processing drug: dexibuprofen
# Runtime: 4.42 sec.
# Processing drug: dexketoprofen
# Runtime: 4.62 sec.
# Processing drug: dexlansoprazole
# Runtime: 4.57 sec.
# Processing drug: dexmedetomidine
# Runtime: 4.61 sec.
# Processing drug: dexmedetomidine hydrochloride
# Runtime: 4.60 sec.
# Processing drug: dexmethylphenidate
# Runtime: 5.11 sec.
# Processing drug: dextroamphetamine
# Runtime: 4.59 sec.
# Processing drug: dextromethorphan
# Runtime: 4.62 sec.
# Processing drug: dextrothyroxine
# Runtime: 4.55 sec.
# Processing drug: dezocine
# Runtime: 4.50 sec.
# Processing drug: diacerein
# Runtime: 4.64 sec.
# Processing drug: diazepam
# Runtime: 4.55 sec.
# Processing drug: diazoxide
# Runtime: 4.57 sec.
# Processing drug: dibenzepin
# Runtime: 4.60 sec.
# Processing drug: dibotermin alfa
# Runtime: 4.50 sec.
# Processing drug: dibucaine
# Runtime: 4.52 sec.
# Processing drug: dichlorobenzyl alcohol
# Runtime: 4.62 sec.
# Processing drug: dichlorphenamide
# Runtime: 5.23 sec.
# Processing drug: diclofenac
# Runtime: 5.66 sec.
# Processing drug: diclofenac sodium
# Runtime: 4.93 sec.
# Processing drug: diclofenamide
# Runtime: 5.13 sec.
# Processing drug: dicloxacillin
# Runtime: 4.76 sec.
# Processing drug: dicoumarol
# Runtime: 4.82 sec.
# Processing drug: dicumarol
# Runtime: 4.80 sec.
# Processing drug: dicyclomine
# Runtime: 4.83 sec.
# Processing drug: didanosine
# Runtime: 4.80 sec.
# Processing drug: dienestrol
# Runtime: 4.75 sec.
# Processing drug: dienogest
# Runtime: 4.82 sec.
# Processing drug: diethylstilbestrol
# 600/2244 drugs processed
# Runtime: 4.93 sec.
# Processing drug: difelikefalin
# Runtime: 5.27 sec.
# Processing drug: diflorasone
# Runtime: 6.36 sec.
# Processing drug: diflorasone diacetate
# Runtime: 4.90 sec.
# Processing drug: diflunisal
# Runtime: 5.41 sec.
# Processing drug: difluprednate
# Runtime: 4.75 sec.
# Processing drug: digitoxin
# Runtime: 4.98 sec.
# Processing drug: digoxin
# Runtime: 6.40 sec.
# Processing drug: dihydro-alpha-ergocryptine
# Runtime: 4.84 sec.
# Processing drug: dihydroergotamine
# Runtime: 5.04 sec.
# Processing drug: dihydroergotamine mesylate
# Runtime: 4.93 sec.
# Processing drug: diltiazem
# Runtime: 4.86 sec.
# Processing drug: diltiazem hydrochloride
# Runtime: 5.43 sec.
# Processing drug: dimenhydrinate
# Runtime: 5.08 sec.
# Processing drug: dimercaprol
# Runtime: 6.27 sec.
# Processing drug: dimethindene
# Runtime: 5.96 sec.
# Processing drug: dimethyl fumarate
# Runtime: 5.13 sec.
# Processing drug: dimethyl sulfoxide
# Runtime: 4.99 sec.
# Processing drug: dimetindene
# Runtime: 4.88 sec.
# Processing drug: dinoprost
# Runtime: 5.44 sec.
# Processing drug: dinoprost tromethamine
# Runtime: 4.96 sec.
# Processing drug: dinoprostone
# Runtime: 5.52 sec.
# Processing drug: diosmin
# Runtime: 5.09 sec.
# Processing drug: diphenhydramine
# Runtime: 4.97 sec.
# Processing drug: diphenidol
# Runtime: 4.96 sec.
# Processing drug: diphenidol hydrochloride
# Runtime: 5.69 sec.
# Processing drug: diphenoxylate
# Runtime: 5.64 sec.
# Processing drug: diphenylpyraline
# Runtime: 4.85 sec.
# Processing drug: dipivefrin hydrochloride
# Runtime: 4.71 sec.
# Processing drug: dipyridamole
# Runtime: 5.09 sec.
# Processing drug: dipyrithione
# Runtime: 5.18 sec.
# Processing drug: disopyramide
# Runtime: 5.01 sec.
# Processing drug: disulfiram
# Runtime: 5.12 sec.
# Processing drug: dl-methylephedrine
# Runtime: 5.02 sec.
# Processing drug: dobutamine
# Runtime: 5.06 sec.
# Processing drug: docetaxel
# Runtime: 4.84 sec.
# Processing drug: docetaxel anhydrous
# Runtime: 4.98 sec.
# Processing drug: doconexent
# Runtime: 4.97 sec.
# Processing drug: dofetilide
# Runtime: 4.85 sec.
# Processing drug: dolasetron
# Runtime: 4.75 sec.
# Processing drug: dolutegravir
# Runtime: 4.68 sec.
# Processing drug: domperidone
# Runtime: 4.75 sec.
# Processing drug: donepezil
# Runtime: 5.31 sec.
# Processing drug: donepezil hydrochloride
# Runtime: 4.83 sec.
# Processing drug: dopamine
# Runtime: 5.39 sec.
# Processing drug: dopamine hydrochloride
# Runtime: 4.82 sec.
# Processing drug: doravirine
# Runtime: 4.85 sec.
# Processing drug: doripenem
# Runtime: 4.89 sec.
# Processing drug: dornase alfa
# Runtime: 4.85 sec.
# Processing drug: dorzolamide
# Runtime: 5.92 sec.
# Processing drug: dostarlimab
# 650/2244 drugs processed
# Runtime: 4.91 sec.
# Processing drug: dosulepin
# Runtime: 4.93 sec.
# Processing drug: doxapram
# Runtime: 4.79 sec.
# Processing drug: doxazosin
# Runtime: 4.92 sec.
# Processing drug: doxazosin mesylate
# Runtime: 5.03 sec.
# Processing drug: doxepin
# Runtime: 6.22 sec.
# Processing drug: doxorubicin
# Runtime: 5.84 sec.
# Processing drug: doxorubicin hydrochloride
# Runtime: 6.26 sec.
# Processing drug: doxycycline anhydrous
# Runtime: 5.28 sec.
# Processing drug: doxylamine
# Runtime: 5.45 sec.
# Processing drug: dronabinol
# Runtime: 5.39 sec.
# Processing drug: dronedarone
# Runtime: 4.89 sec.
# Processing drug: dronedarone hydrochloride
# Runtime: 4.89 sec.
# Processing drug: droperidol
# Runtime: 4.89 sec.
# Processing drug: drospirenone
# Runtime: 4.86 sec.
# Processing drug: droxidopa
# Runtime: 4.85 sec.
# Processing drug: dulaglutide
# Runtime: 4.84 sec.
# Processing drug: duloxetine
# Runtime: 4.79 sec.
# Processing drug: dupilumab
# Runtime: 4.71 sec.
# Processing drug: durvalumab
# Runtime: 4.62 sec.
# Processing drug: dutasteride
# Runtime: 4.82 sec.
# Processing drug: duvelisib
# Runtime: 4.76 sec.
# Processing drug: dyclonine
# Runtime: 4.83 sec.
# Processing drug: ecallantide
# Runtime: 5.97 sec.
# Processing drug: echothiophate
# Runtime: 4.75 sec.
# Processing drug: econazole
# Runtime: 5.08 sec.
# Processing drug: econazole nitrate
# Runtime: 4.95 sec.
# Processing drug: eculizumab
# Runtime: 5.05 sec.
# Processing drug: edotreotide gallium ga-68
# Runtime: 4.93 sec.
# Processing drug: edoxaban
# Runtime: 4.94 sec.
# Processing drug: edrophonium
# Runtime: 5.39 sec.
# Processing drug: edrophonium chloride
# Runtime: 5.18 sec.
# Processing drug: efanesoctocog alfa
# Runtime: 4.80 sec.
# Processing drug: efavirenz
# Runtime: 4.96 sec.
# Processing drug: efbemalenograstim alfa
# Runtime: 5.43 sec.
# Processing drug: efgartigimod alfa
# Runtime: 5.16 sec.
# Processing drug: eflapegrastim
# Runtime: 4.89 sec.
# Processing drug: eflornithine
# Runtime: 4.93 sec.
# Processing drug: efmoroctocog alfa
# Runtime: 4.98 sec.
# Processing drug: eftrenonacog alfa
# Runtime: 5.25 sec.
# Processing drug: elacestrant
# Runtime: 4.81 sec.
# Processing drug: elafibranor
# Runtime: 4.84 sec.
# Processing drug: elagolix
# Runtime: 4.87 sec.
# Processing drug: elagolix sodium
# Runtime: 4.86 sec.
# Processing drug: eletriptan
# Runtime: 4.99 sec.
# Processing drug: elexacaftor
# Runtime: 4.86 sec.
# Processing drug: eliglustat
# Runtime: 5.29 sec.
# Processing drug: elotuzumab
# Runtime: 5.02 sec.
# Processing drug: elranatamab
# Runtime: 4.82 sec.
# Processing drug: eltrombopag
# Runtime: 4.91 sec.
# Processing drug: eluxadoline
# 700/2244 drugs processed
# Runtime: 4.79 sec.
# Processing drug: elvitegravir
# Runtime: 4.80 sec.
# Processing drug: emapalumab
# Runtime: 5.96 sec.
# Processing drug: emedastine
# Runtime: 5.91 sec.
# Processing drug: emicizumab
# Runtime: 5.30 sec.
# Processing drug: empagliflozin
# Runtime: 5.87 sec.
# Processing drug: emtricitabine
# Runtime: 6.15 sec.
# Processing drug: enalapril
# Runtime: 5.46 sec.
# Processing drug: enasidenib
# Runtime: 5.01 sec.
# Processing drug: enasidenib mesylate
# Runtime: 4.92 sec.
# Processing drug: encorafenib
# Runtime: 4.87 sec.
# Processing drug: enfortumab vedotin
# Runtime: 5.25 sec.
# Processing drug: enoxacin
# Runtime: 5.19 sec.
# Processing drug: enoxaparin
# Runtime: 4.77 sec.
# Processing drug: enoximone
# Runtime: 4.77 sec.
# Processing drug: ensartinib
# Runtime: 4.68 sec.
# Processing drug: entacapone
# Runtime: 5.02 sec.
# Processing drug: entrectinib
# Runtime: 5.06 sec.
# Processing drug: enzalutamide
# Runtime: 4.96 sec.
# Processing drug: epcoritamab
# Runtime: 5.80 sec.
# Processing drug: ephedrine
# Runtime: 4.90 sec.
# Processing drug: epinastine
# Runtime: 4.86 sec.
# Processing drug: epinephrine
# Runtime: 4.78 sec.
# Processing drug: epinephrine bitartrate
# Runtime: 4.71 sec.
# Processing drug: epirubicin
# Runtime: 4.98 sec.
# Processing drug: eplerenone
# Runtime: 4.78 sec.
# Processing drug: epoprostenol
# Runtime: 4.73 sec.
# Processing drug: eprosartan
# Runtime: 4.77 sec.
# Processing drug: eptifibatide
# Runtime: 4.70 sec.
# Processing drug: eptinezumab
# Runtime: 4.77 sec.
# Processing drug: erdafitinib
# Runtime: 4.72 sec.
# Processing drug: erenumab
# Runtime: 4.72 sec.
# Processing drug: ergocalciferol
# Runtime: 4.62 sec.
# Processing drug: ergometrine
# Runtime: 4.68 sec.
# Processing drug: ergonovine
# Runtime: 4.64 sec.
# Processing drug: ergotamine
# Runtime: 4.66 sec.
# Processing drug: eribulin
# Runtime: 4.67 sec.
# Processing drug: erlotinib
# Runtime: 5.06 sec.
# Processing drug: erlotinib hydrochloride
# Runtime: 4.90 sec.
# Processing drug: ertapenem sodium
# Runtime: 4.76 sec.
# Processing drug: ertugliflozin
# Runtime: 4.73 sec.
# Processing drug: erythromycin
# Runtime: 4.71 sec.
# Processing drug: erythromycin estolate
# Runtime: 5.15 sec.
# Processing drug: erythropoietin
# Runtime: 5.27 sec.
# Processing drug: escitalopram
# Runtime: 6.87 sec.
# Processing drug: escitalopram oxalate
# Runtime: 6.38 sec.
# Processing drug: esketamine
# Runtime: 5.29 sec.
# Processing drug: eslicarbazepine
# Runtime: 6.44 sec.
# Processing drug: eslicarbazepine acetate
# Runtime: 5.16 sec.
# Processing drug: esmolol
# Runtime: 4.96 sec.
# Processing drug: esomeprazole
# 750/2244 drugs processed
# Runtime: 5.05 sec.
# Processing drug: estetrol
# Runtime: 4.95 sec.
# Processing drug: estradiol
# Runtime: 5.09 sec.
# Processing drug: estradiol acetate
# Runtime: 4.89 sec.
# Processing drug: estradiol benzoate
# Runtime: 4.94 sec.
# Processing drug: estradiol cypionate
# Runtime: 4.87 sec.
# Processing drug: estradiol valerate
# Runtime: 4.75 sec.
# Processing drug: estramustine phosphate
# Runtime: 4.81 sec.
# Processing drug: estriol
# Runtime: 4.78 sec.
# Processing drug: estrone
# Runtime: 4.82 sec.
# Processing drug: estrone sulfate
# Runtime: 6.61 sec.
# Processing drug: estrone sulfuric acid
# Runtime: 5.58 sec.
# Processing drug: eszopiclone
# Runtime: 5.62 sec.
# Processing drug: etacrynic acid
# Runtime: 6.23 sec.
# Processing drug: etafedrine
# Runtime: 5.33 sec.
# Processing drug: etanercept
# Runtime: 5.30 sec.
# Processing drug: etelcalcetide
# Runtime: 6.43 sec.
# Processing drug: ethacrynic acid
# Runtime: 5.23 sec.
# Processing drug: ethambutol hydrochloride
# Runtime: 5.24 sec.
# Processing drug: ethamivan
# Runtime: 5.52 sec.
# Processing drug: ethanol
# Runtime: 5.03 sec.
# Processing drug: ethanolamine oleate
# Runtime: 5.08 sec.
# Processing drug: ethinyl estradiol
# Runtime: 5.12 sec.
# Processing drug: ethinylestradiol
# Runtime: 5.51 sec.
# Processing drug: ethopropazine
# Runtime: 5.09 sec.
# Processing drug: ethopropazine hydrochloride
# Runtime: 5.11 sec.
# Processing drug: ethosuximide
# Runtime: 5.04 sec.
# Processing drug: ethotoin
# Runtime: 5.20 sec.
# Processing drug: ethoxzolamide
# Runtime: 5.29 sec.
# Processing drug: ethylestrenol
# Runtime: 5.19 sec.
# Processing drug: ethynodiol diacetate
# Runtime: 5.34 sec.
# Processing drug: etidocaine
# Runtime: 5.07 sec.
# Processing drug: etidronic acid
# Runtime: 4.91 sec.
# Processing drug: etilefrine
# Runtime: 4.78 sec.
# Processing drug: etodolac
# Runtime: 4.88 sec.
# Processing drug: etomidate
# Runtime: 4.89 sec.
# Processing drug: etonogestrel
# Runtime: 4.74 sec.
# Processing drug: etoposide
# Runtime: 4.83 sec.
# Processing drug: etoricoxib
# Runtime: 5.05 sec.
# Processing drug: etranacogene dezaparvovec
# Runtime: 5.02 sec.
# Processing drug: etrasimod
# Runtime: 5.57 sec.
# Processing drug: etravirine
# Runtime: 4.86 sec.
# Processing drug: everolimus
# Runtime: 4.80 sec.
# Processing drug: evinacumab
# Runtime: 4.92 sec.
# Processing drug: evolocumab
# Runtime: 5.36 sec.
# Processing drug: exemestane
# Runtime: 5.31 sec.
# Processing drug: exenatide
# Runtime: 5.33 sec.
# Processing drug: ezetimibe
# Runtime: 5.86 sec.
# Processing drug: ezogabine
# Runtime: 5.45 sec.
# Processing drug: famotidine
# Runtime: 5.17 sec.
# Processing drug: faricimab
# 800/2244 drugs processed
# Runtime: 5.33 sec.
# Processing drug: febuxostat
# Runtime: 5.12 sec.
# Processing drug: fedratinib
# Runtime: 5.37 sec.
# Processing drug: felbamate
# Runtime: 4.83 sec.
# Processing drug: felbinac
# Runtime: 4.95 sec.
# Processing drug: felodipine
# Runtime: 4.83 sec.
# Processing drug: fenbendazole
# Runtime: 4.97 sec.
# Processing drug: fenbufen
# Runtime: 4.78 sec.
# Processing drug: fenclofenac
# Runtime: 4.77 sec.
# Processing drug: fenofibrate
# Runtime: 4.87 sec.
# Processing drug: fenofibric acid
# Runtime: 4.80 sec.
# Processing drug: fenoldopam
# Runtime: 4.76 sec.
# Processing drug: fenoldopam mesylate
# Runtime: 4.92 sec.
# Processing drug: fenoprofen
# Runtime: 5.68 sec.
# Processing drug: fenoterol
# Runtime: 4.87 sec.
# Processing drug: fentanyl
# Runtime: 4.93 sec.
# Processing drug: feprazone
# Runtime: 4.93 sec.
# Processing drug: ferric pyrophosphate
# Runtime: 4.81 sec.
# Processing drug: ferric pyrophosphate citrate
# Runtime: 4.91 sec.
# Processing drug: ferrous sulfate anhydrous
# Runtime: 4.95 sec.
# Processing drug: fesoterodine
# Runtime: 4.83 sec.
# Processing drug: fexofenadine
# Runtime: 4.92 sec.
# Processing drug: fexofenadine hydrochloride
# Runtime: 5.45 sec.
# Processing drug: fezolinetant
# Runtime: 6.38 sec.
# Processing drug: filgotinib
# Runtime: 5.86 sec.
# Processing drug: filgrastim
# Runtime: 5.12 sec.
# Processing drug: finasteride
# Runtime: 4.95 sec.
# Processing drug: finerenone
# Runtime: 5.01 sec.
# Processing drug: fingolimod
# Runtime: 4.84 sec.
# Processing drug: fingolimod hydrochloride
# Runtime: 4.92 sec.
# Processing drug: fitusiran
# Runtime: 4.95 sec.
# Processing drug: flavin adenine dinucleotide
# Runtime: 4.89 sec.
# Processing drug: flavoxate
# Runtime: 4.81 sec.
# Processing drug: flecainide
# Runtime: 4.88 sec.
# Processing drug: flibanserin
# Runtime: 4.82 sec.
# Processing drug: florbetaben f-18
# Runtime: 5.36 sec.
# Processing drug: florbetaben f18
# Runtime: 5.57 sec.
# Processing drug: flortaucipir f-18
# Runtime: 5.93 sec.
# Processing drug: flotufolastat f-18
# Runtime: 6.74 sec.
# Processing drug: floxacillin
# Runtime: 5.68 sec.
# Processing drug: floxuridine
# Runtime: 5.09 sec.
# Processing drug: fluciclovine (18f)
# Runtime: 4.91 sec.
# Processing drug: fluconazole
# Runtime: 5.00 sec.
# Processing drug: fludarabine
# Runtime: 4.84 sec.
# Processing drug: fludarabine phosphate
# /Users/hannahbazin/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/numpy/_core/fromnumeric.py:3596: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /Users/hannahbazin/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/numpy/_core/_methods.py:138: RuntimeWarning: invalid value encountered in scalar divide
#   ret = ret.dtype.type(ret / rcount)
# Runtime: 5.09 sec.
# Processing drug: fludrocortisone
# Runtime: 5.01 sec.
# Processing drug: fludrocortisone acetate
# Runtime: 4.74 sec.
# Processing drug: flufenamic acid
# Runtime: 4.89 sec.
# Processing drug: flumazenil
# Runtime: 5.01 sec.
# Processing drug: flumethasone
# Runtime: 4.92 sec.
# Processing drug: flunarizine
# 850/2244 drugs processed
# Runtime: 4.98 sec.
# Processing drug: flunarizine hydrochloride
# Runtime: 4.74 sec.
# Processing drug: flunisolide
# Runtime: 4.87 sec.
# Processing drug: flunitrazepam
# Runtime: 4.81 sec.
# Processing drug: fluocinolone acetonide
# Runtime: 4.72 sec.
# Processing drug: fluocinonide
# Runtime: 4.88 sec.
# Processing drug: fluorometholone
# Runtime: 4.78 sec.
# Processing drug: fluorouracil
# Runtime: 4.81 sec.
# Processing drug: fluoxetine
# Runtime: 4.82 sec.
# Processing drug: fluoxetine hydrochloride
# Runtime: 4.88 sec.
# Processing drug: fluoxymesterone
# Runtime: 5.14 sec.
# Processing drug: fluphenazine
# Runtime: 5.57 sec.
# Processing drug: flurandrenolide
# Runtime: 4.96 sec.
# Processing drug: flurbiprofen
# Runtime: 5.08 sec.
# Processing drug: flurpiridaz f-18
# Runtime: 4.90 sec.
# Processing drug: fluspirilene
# Runtime: 4.88 sec.
# Processing drug: flutamide
# Runtime: 5.07 sec.
# Processing drug: flutemetamol (18f)
# Runtime: 5.05 sec.
# Processing drug: fluticasone furoate
# Runtime: 5.02 sec.
# Processing drug: fluticasone propionate
# Runtime: 4.78 sec.
# Processing drug: flutrimazole
# Runtime: 4.81 sec.
# Processing drug: fluvastatin
# Runtime: 4.92 sec.
# Processing drug: fluvoxamine
# Runtime: 4.78 sec.
# Processing drug: follitropin
# Runtime: 4.97 sec.
# Processing drug: fomepizole
# Runtime: 4.65 sec.
# Processing drug: fondaparinux
# Runtime: 4.73 sec.
# Processing drug: fondaparinux sodium
# Runtime: 4.70 sec.
# Processing drug: foreskin fibroblast (neonatal)
# Runtime: 4.88 sec.
# Processing drug: foreskin keratinocyte (neonatal)
# Runtime: 4.99 sec.
# Processing drug: formestane
# Runtime: 4.80 sec.
# Processing drug: formic acid
# Runtime: 4.79 sec.
# Processing drug: formoterol
# Runtime: 4.77 sec.
# Processing drug: fosaprepitant
# Runtime: 4.86 sec.
# Processing drug: foscarnet
# Runtime: 4.72 sec.
# Processing drug: foscarnet sodium
# Runtime: 4.84 sec.
# Processing drug: fosdenopterin
# Runtime: 5.35 sec.
# Processing drug: fosinopril
# Runtime: 4.87 sec.
# Processing drug: fosnetupitant
# Runtime: 4.82 sec.
# Processing drug: fosphenytoin
# Runtime: 4.84 sec.
# Processing drug: fostamatinib
# Runtime: 4.74 sec.
# Processing drug: fostamatinib disodium
# Runtime: 4.83 sec.
# Processing drug: fremanezumab
# Runtime: 4.78 sec.
# Processing drug: frovatriptan
# Runtime: 4.73 sec.
# Processing drug: frovatriptan succinate
# Runtime: 4.68 sec.
# Processing drug: fruquintinib
# Runtime: 4.72 sec.
# Processing drug: fulvestrant
# Runtime: 4.89 sec.
# Processing drug: fumaric acid
# Runtime: 4.70 sec.
# Processing drug: furosemide
# Runtime: 4.94 sec.
# Processing drug: fusidic acid
# Runtime: 5.58 sec.
# Processing drug: futibatinib
# Runtime: 5.22 sec.
# Processing drug: gabapentin
# 900/2244 drugs processed
# Runtime: 5.64 sec.
# Processing drug: gabapentin enacarbil
# Runtime: 5.16 sec.
# Processing drug: gadofosveset trisodium
# Runtime: 5.06 sec.
# Processing drug: galantamine
# Runtime: 4.95 sec.
# Processing drug: galantamine hydrobromide
# Runtime: 4.81 sec.
# Processing drug: galcanezumab
# Runtime: 4.96 sec.
# Processing drug: gallamine
# Runtime: 5.09 sec.
# Processing drug: gallamine triethiodide
# Runtime: 4.84 sec.
# Processing drug: gamma-aminobutyric acid
# Runtime: 5.02 sec.
# Processing drug: gamolenic acid
# Runtime: 5.52 sec.
# Processing drug: ganaxolone
# Runtime: 5.59 sec.
# Processing drug: ganciclovir
# Runtime: 4.92 sec.
# Processing drug: ganirelix
# Runtime: 5.01 sec.
# Processing drug: ganirelix acetate
# Runtime: 4.83 sec.
# Processing drug: gatifloxacin
# Runtime: 5.76 sec.
# Processing drug: gefitinib
# Runtime: 6.84 sec.
# Processing drug: gemcitabine
# Runtime: 5.10 sec.
# Processing drug: gemfibrozil
# Runtime: 5.04 sec.
# Processing drug: gemifloxacin
# Runtime: 4.88 sec.
# Processing drug: gemifloxacin mesylate
# Runtime: 5.24 sec.
# Processing drug: gemtuzumab ozogamicin
# Runtime: 6.26 sec.
# Processing drug: gentamicin
# Runtime: 9.10 sec.
# Processing drug: gentamicin sulfate
# Runtime: 7.05 sec.
# Processing drug: gentian violet
# Runtime: 5.33 sec.
# Processing drug: gepirone
# Runtime: 5.12 sec.
# Processing drug: gestrinone
# Runtime: 5.10 sec.
# Processing drug: gilteritinib
# Runtime: 5.55 sec.
# Processing drug: gimeracil
# Runtime: 5.64 sec.
# Processing drug: glasdegib
# Runtime: 5.59 sec.
# Processing drug: gliclazide
# Runtime: 5.80 sec.
# Processing drug: glimepiride
# ...
# Runtime: 6.23 sec.
# Processing drug: thymol
# Runtime: 7.05 sec.
# Processing drug: thyroid, porcine
# Runtime: 7.04 sec.
# Processing drug: thyrotropin alfa
# Runtime: 6.53 sec.
# Processing drug: tiagabine
# Runtime: 7.66 sec.
# Processing drug: tiagabine hydrochloride
# Runtime: 7.01 sec.
# Processing drug: tiaprofenic acid
# Runtime: 7.24 sec.
# Processing drug: tibolone
# Runtime: 6.66 sec.
# Processing drug: ticagrelor
# Runtime: 6.70 sec.
# Processing drug: ticlopidine
# Runtime: 6.97 sec.
# Processing drug: tiludronate disodium
# Runtime: 6.37 sec.
# Processing drug: tiludronic acid
# Runtime: 6.83 sec.
# Processing drug: timolol
# Runtime: 6.27 sec.
# Processing drug: tinzaparin
# Runtime: 6.74 sec.
# Processing drug: tioconazole
# Runtime: 5.90 sec.
# Processing drug: tiotropium
# Runtime: 6.15 sec.
# Processing drug: tiotropium bromide
# 2050/2244 drugs processed
# Runtime: 6.56 sec.
# Processing drug: tipiracil
# Runtime: 6.08 sec.
# Processing drug: tipiracil hydrochloride
# Runtime: 6.46 sec.
# Processing drug: tipranavir
# Runtime: 6.21 sec.
# Processing drug: tirbanibulin
# Runtime: 6.18 sec.
# Processing drug: tirofiban
# Runtime: 6.66 sec.
# Processing drug: tirzepatide
# Runtime: 6.04 sec.
# Processing drug: tisagenlecleucel
# Runtime: 9.16 sec.
# Processing drug: tislelizumab
# Runtime: 7.01 sec.
# Processing drug: tisotumab vedotin
# Runtime: 6.99 sec.
# Processing drug: tivozanib
# Runtime: 7.00 sec.
# Processing drug: tizanidine
# Runtime: 7.36 sec.
# Processing drug: tizanidine hydrochloride
# Runtime: 7.45 sec.
# Processing drug: tocilizumab
# Runtime: 7.33 sec.
# Processing drug: tocofersolan
# Runtime: 7.06 sec.
# Processing drug: tofacitinib
# Runtime: 6.64 sec.
# Processing drug: tofacitinib citrate
# Runtime: 5.47 sec.
# Processing drug: tolazamide
# Runtime: 5.97 sec.
# Processing drug: tolazoline
# Runtime: 7.39 sec.
# Processing drug: tolazoline hydrochloride
# Runtime: 6.35 sec.
# Processing drug: tolbutamide
# Runtime: 6.71 sec.
# Processing drug: tolcapone
# Runtime: 6.01 sec.
# Processing drug: tolfenamic acid
# Runtime: 6.29 sec.
# Processing drug: tolmetin
# Runtime: 6.39 sec.
# Processing drug: tolnaftate
# Runtime: 8.79 sec.
# Processing drug: tolrestat
# Runtime: 7.22 sec.
# Processing drug: tolterodine
# Runtime: 6.88 sec.
# Processing drug: tolvaptan
# Runtime: 7.04 sec.
# Processing drug: topiramate
# Runtime: 7.04 sec.
# Processing drug: topotecan
# Runtime: 6.37 sec.
# Processing drug: topotecan hydrochloride
# Runtime: 5.83 sec.
# Processing drug: torasemide
# Runtime: 5.94 sec.
# Processing drug: toremifene
# Runtime: 7.57 sec.
# Processing drug: toremifene citrate
# Runtime: 6.71 sec.
# Processing drug: toripalimab
# Runtime: 5.94 sec.
# Processing drug: torsemide
# Runtime: 5.95 sec.
# Processing drug: tovorafenib
# Runtime: 6.04 sec.
# Processing drug: tramadol
# Runtime: 6.38 sec.
# Processing drug: trametinib
# Runtime: 6.64 sec.
# Processing drug: trandolapril
# Runtime: 5.82 sec.
# Processing drug: tranexamic acid
# Runtime: 7.08 sec.
# Processing drug: tranylcypromine
# Runtime: 7.15 sec.
# Processing drug: trastuzumab
# Runtime: 7.78 sec.
# Processing drug: trastuzumab deruxtecan
# Runtime: 5.45 sec.
# Processing drug: trastuzumab emtansine
# Runtime: 5.60 sec.
# Processing drug: travoprost
# Runtime: 5.74 sec.
# Processing drug: trazodone
# Runtime: 5.96 sec.
# Processing drug: trazodone hydrochloride
# Runtime: 6.14 sec.
# Processing drug: tremelimumab
# Runtime: 6.43 sec.
# Processing drug: treprostinil
# Runtime: 6.58 sec.
# Processing drug: tretinoin
# 2100/2244 drugs processed
# Runtime: 8.11 sec.
# Processing drug: triamcinolone
# Runtime: 10.02 sec.
# Processing drug: triamcinolone acetonide
# Runtime: 8.34 sec.
# Processing drug: triamterene
# Runtime: 6.95 sec.
# Processing drug: triazolam
# Runtime: 6.58 sec.
# Processing drug: trichlormethiazide
# Runtime: 7.02 sec.
# Processing drug: triclabendazole
# Runtime: 6.29 sec.
# Processing drug: triclocarban
# Runtime: 5.85 sec.
# Processing drug: triclosan
# Runtime: 5.96 sec.
# Processing drug: trientine
# Runtime: 6.56 sec.
# Processing drug: trifarotene
# Runtime: 10.89 sec.
# Processing drug: trifluoperazine
# Runtime: 9.04 sec.
# Processing drug: trifluperidol
# Runtime: 9.11 sec.
# Processing drug: triflupromazine
# Runtime: 8.69 sec.
# Processing drug: triflupromazine hydrochloride
# Runtime: 7.69 sec.
# Processing drug: trifluridine
# Runtime: 6.80 sec.
# Processing drug: trihexyphenidyl
# Runtime: 7.09 sec.
# Processing drug: trihexyphenidyl hydrochloride
# Runtime: 7.07 sec.
# Processing drug: trilaciclib
# Runtime: 5.77 sec.
# Processing drug: trimebutine
# Runtime: 5.47 sec.
# Processing drug: trimethaphan
# Runtime: 6.21 sec.
# Processing drug: trimethobenzamide
# Runtime: 6.05 sec.
# Processing drug: trimethoprim
# Runtime: 5.07 sec.
# Processing drug: trimetrexate
# Runtime: 5.43 sec.
# Processing drug: trimipramine
# Runtime: 5.05 sec.
# Processing drug: trioxsalen
# Runtime: 6.59 sec.
# Processing drug: tripelennamine
# Runtime: 5.60 sec.
# Processing drug: triprolidine
# Runtime: 7.17 sec.
# Processing drug: triptorelin
# Runtime: 6.89 sec.
# Processing drug: troglitazone
# Runtime: 5.71 sec.
# Processing drug: trolamine salicylate
# Runtime: 5.47 sec.
# Processing drug: troleandomycin
# Runtime: 5.77 sec.
# Processing drug: tropicamide
# Runtime: 5.69 sec.
# Processing drug: tropisetron
# Runtime: 6.00 sec.
# Processing drug: trospium chloride
# Runtime: 5.41 sec.
# Processing drug: trovafloxacin
# Runtime: 5.82 sec.
# Processing drug: tryptophan
# Runtime: 5.62 sec.
# Processing drug: tuberculin purified protein derivative
# Runtime: 5.55 sec.
# Processing drug: tubocurarine
# Runtime: 5.76 sec.
# Processing drug: tucatinib
# Runtime: 5.36 sec.
# Processing drug: tulobuterol
# Runtime: 5.02 sec.
# Processing drug: turoctocog alfa
# Runtime: 5.31 sec.
# Processing drug: turoctocog alfa pegol
# Runtime: 5.28 sec.
# Processing drug: tyloxapol
# Runtime: 5.80 sec.
# Processing drug: ublituximab
# Runtime: 5.68 sec.
# Processing drug: ubrogepant
# Runtime: 5.04 sec.
# Processing drug: udenafil
# Runtime: 5.23 sec.
# Processing drug: ulipristal
# Runtime: 6.18 sec.
# Processing drug: ulipristal acetate
# Runtime: 7.06 sec.
# Processing drug: ulobetasol
# Runtime: 5.73 sec.
# Processing drug: umbralisib
# 2150/2244 drugs processed
# Runtime: 5.28 sec.
# Processing drug: umeclidinium
# Runtime: 4.96 sec.
# Processing drug: umeclidinium bromide
# Runtime: 4.92 sec.
# Processing drug: upadacitinib
# Runtime: 4.90 sec.
# Processing drug: urea
# Runtime: 4.85 sec.
# Processing drug: ursodeoxycholic acid
# Runtime: 4.85 sec.
# Processing drug: ursodiol
# Runtime: 4.87 sec.
# Processing drug: ustekinumab
# Runtime: 4.80 sec.
# Processing drug: vaborbactam
# Runtime: 4.98 sec.
# Processing drug: vadadustat
# Runtime: 4.97 sec.
# Processing drug: valacyclovir
# Runtime: 4.93 sec.
# Processing drug: valbenazine
# Runtime: 5.24 sec.
# Processing drug: valdecoxib
# Runtime: 6.07 sec.
# Processing drug: valproic acid
# Runtime: 4.95 sec.
# Processing drug: valrubicin
# Runtime: 4.78 sec.
# Processing drug: valsartan
# Runtime: 4.86 sec.
# Processing drug: vancomycin
# Runtime: 4.69 sec.
# Processing drug: vandetanib
# Runtime: 5.02 sec.
# Processing drug: vanzacaftor
# Runtime: 4.84 sec.
# Processing drug: vardenafil
# Runtime: 5.08 sec.
# Processing drug: vardenafil hydrochloride
# Runtime: 4.91 sec.
# Processing drug: varenicline
# Runtime: 5.04 sec.
# Processing drug: vasopressin
# Runtime: 5.01 sec.
# Processing drug: vecuronium
# Runtime: 7.95 sec.
# Processing drug: vecuronium bromide
# Runtime: 6.57 sec.
# Processing drug: vedolizumab
# Runtime: 6.41 sec.
# Processing drug: velaglucerase alfa
# Runtime: 10.09 sec.
# Processing drug: vemurafenib
# Runtime: 9.80 sec.
# Processing drug: venetoclax
# Runtime: 10.23 sec.
# Processing drug: venlafaxine
# Runtime: 7.29 sec.
# Processing drug: venlafaxine hydrochloride
# Runtime: 6.50 sec.
# Processing drug: verapamil
# Runtime: 6.09 sec.
# Processing drug: verapamil hydrochloride
# Runtime: 6.35 sec.
# Processing drug: vericiguat
# Runtime: 7.64 sec.
# Processing drug: vernakalant
# Runtime: 6.38 sec.
# Processing drug: vernakalant hydrochloride
# Runtime: 6.44 sec.
# Processing drug: verteporfin
# Runtime: 5.84 sec.
# Processing drug: vibegron
# Runtime: 5.29 sec.
# Processing drug: vidarabine
# Runtime: 5.45 sec.
# Processing drug: vigabatrin
# Runtime: 5.55 sec.
# Processing drug: vilazodone
# Runtime: 7.70 sec.
# Processing drug: vilazodone hydrochloride
# Runtime: 6.13 sec.
# Processing drug: vildagliptin
# Runtime: 5.83 sec.
# Processing drug: viloxazine
# Runtime: 7.23 sec.
# Processing drug: vinblastine
# Runtime: 6.31 sec.
# Processing drug: vinblastine sulfate
# Runtime: 7.24 sec.
# Processing drug: vincristine
# Runtime: 6.47 sec.
# Processing drug: vinflunine
# Runtime: 5.94 sec.
# Processing drug: vinorelbine
# Runtime: 8.53 sec.
# Processing drug: vinpocetine
# Runtime: 7.69 sec.
# Processing drug: vismodegib
# 2200/2244 drugs processed
# Runtime: 6.67 sec.
# Processing drug: voclosporin
# Runtime: 6.16 sec.
# Processing drug: volanesorsen
# Runtime: 5.87 sec.
# Processing drug: von willebrand factor human
# Runtime: 5.76 sec.
# Processing drug: vonicog alfa
# Runtime: 6.03 sec.
# Processing drug: vorapaxar
# Runtime: 6.57 sec.
# Processing drug: vorasidenib
# Runtime: 6.71 sec.
# Processing drug: voretigene neparvovec
# Runtime: 6.02 sec.
# Processing drug: voriconazole
# Runtime: 7.19 sec.
# Processing drug: vorinostat
# Runtime: 5.51 sec.
# Processing drug: vortioxetine
# Runtime: 5.51 sec.
# Processing drug: vosoritide
# Runtime: 5.37 sec.
# Processing drug: voxelotor
# Runtime: 5.59 sec.
# Processing drug: warfarin
# Runtime: 5.51 sec.
# Processing drug: xamoterol
# Runtime: 5.86 sec.
# Processing drug: xamoterol fumarate
# Runtime: 5.58 sec.
# Processing drug: xanomeline
# Runtime: 7.30 sec.
# Processing drug: xylometazoline
# Runtime: 6.79 sec.
# Processing drug: xylometazoline hydrochloride
# Runtime: 5.41 sec.
# Processing drug: yohimbine
# Runtime: 5.91 sec.
# Processing drug: yohimbine hydrochloride
# Runtime: 5.35 sec.
# Processing drug: zafirlukast
# Runtime: 5.52 sec.
# Processing drug: zalcitabine
# Runtime: 5.59 sec.
# Processing drug: zaleplon
# Runtime: 5.30 sec.
# Processing drug: zanamivir
# Runtime: 5.88 sec.
# Processing drug: zanidatamab
# Runtime: 5.66 sec.
# Processing drug: zanubrutinib
# Runtime: 5.76 sec.
# Processing drug: zavegepant
# Runtime: 6.25 sec.
# Processing drug: zenocutuzumab
# Runtime: 7.12 sec.
# Processing drug: ziconotide
# Runtime: 5.69 sec.
# Processing drug: zidovudine
# Runtime: 5.36 sec.
# Processing drug: zileuton
# Runtime: 5.94 sec.
# Processing drug: zilucoplan
# Runtime: 5.10 sec.
# Processing drug: ziprasidone
# Runtime: 5.05 sec.
# Processing drug: zofenopril
# Runtime: 5.16 sec.
# Processing drug: zolbetuximab
# Runtime: 5.29 sec.
# Processing drug: zoledronic acid
# Runtime: 5.59 sec.
# Processing drug: zolmitriptan
# Runtime: 5.76 sec.
# Processing drug: zolpidem
# Runtime: 5.18 sec.
# Processing drug: zonisamide
# Runtime: 5.11 sec.
# Processing drug: zopiclone
# Runtime: 5.80 sec.
# Processing drug: zotepine
# Runtime: 5.81 sec.
# Processing drug: zuclopenthixol
# Runtime: 5.20 sec.
# Processing drug: zuranolone
# Runtime: 5.28 sec.
# Saved results to ../results/humanPVATsn/network_analysis/proximity_step1_key_only.csv
# Top 10 prioritised drugs for step1                             drug  distance    z_score
# 1131                   lecanemab  0.000000 -11.806254
# 836              florbetaben f18  0.000000 -11.806254
# 835             florbetaben f-18  0.000000 -11.806254
# 39                    aducanumab  0.000000 -11.806254
# 867           flutemetamol (18f)  0.000000 -11.806254
# 1635  pioglitazone hydrochloride  0.500000  -7.680816
# 1243                  mecasermin  0.500000  -7.680816
# 1813       rosiglitazone maleate  0.666667  -6.305670
# 691                  elafibranor  0.666667  -6.305670
# 990              hyaluronic acid  0.750000  -5.618097
#
# ===== Processing step2 =====
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 23
#      21 # Run proximity analysis for each step
#      22 for step, path in steps.items():
# ---> 23     run_proximity_analysis(step_name=step,
#      24                            deg_file_path=path["deg_file"],
#      25                            output_csv_path=path["output_csv"],
#      26                            ppi_graph=ppi_graph,
#      27                            drug_to_targets=drug_to_targets,
#      28                            bins=bins,
#      29                            n_random=100,
#      30                            min_bin_size=100,
#      31                            seed=452456)
#
# Cell In[6], line 10, in run_proximity_analysis(step_name, deg_file_path, output_csv_path, ppi_graph, drug_to_targets, bins, n_random, min_bin_size, seed)
#       7 print(f"\n===== Processing {step_name} =====")
#       9 # ========== LOAD DISEASE GENES ==========
# ---> 10 disease_genes = pd.read_csv(deg_file_path, header=None)
#      11 print(len(disease_genes), f"disease genes in {step_name}")
#      12 disease_genes = disease_genes.iloc[:,0].dropna().unique().tolist()
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~/Desktop/Cambridge/Academics/Han_Lab/MPhil/mphil-project/bat_proximity_analysis/lib/python3.9/site-packages/pandas/io/common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '.../results/humanPVATsn/network_analysis/step2_key_genes_only.csv'
